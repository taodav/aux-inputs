# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from tqdm.notebook import tqdm
from collections import namedtuple

from definitions import ROOT_DIR
from unc.utils import load_info

plt.rcParams.update({'font.size': 18})
# Out:
# /Users/ruoyutao/Documents/uncertainty/venv/lib/python3.8/site-packages/jax/_src/lib/__init__.py:33: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "

# %%
all_paths = {
    '2t_nn_prediction': Path(ROOT_DIR, 'results', '2t_nn_prediction')
}

split_by = ['step_size', 'epsilon']
Args = namedtuple('args', split_by)

# %%
def process_dir(dir_path, split_by):
    all_results = {}
        
    for f in tqdm(list(dir_path.iterdir())):
        if not f.is_file() or f.suffix != '.npy':
            continue
        info = load_info(f)
        args = info['args'].item()
        
        hparams = Args(*tuple(args[s] for s in split_by))

        if hparams not in all_results:
            all_results[hparams] = []

#         all_results[hparams].append((info['episode_reward'], args))
        all_results[hparams].append((args, info['avg_episode_loss'], f))


    
    return all_results

# %%
raw_data = {}

for key, v in all_paths.items():
    processed = process_dir(v, split_by)
    
    raw_data[key] = {}
    for hparams, ret in processed.items():
        loss_lst, arg_lst, f_lst = [], [], []
        for r in ret:
            loss_lst.append(r[1])
            arg_lst.append(r[0])
            f_lst.append(r[2])
        raw_data[key][hparams] = {'loss': np.stack(loss_lst), 'args': arg_lst, 'paths': f_lst}
# Out:
#   0%|          | 0/243 [00:00<?, ?it/s]

# %%
# Here we get our best hparams
all_best = {}
best_over = 500

for key, res in raw_data.items():
    stats_list = []
    for args, rew_dict in res.items():
        # we take mean over both time and seeds
        stats_list.append((args, rew_dict['loss'][:, -best_over].mean(), rew_dict['loss'], rew_dict['args'], rew_dict['paths']))
    all_best[key] = sorted(stats_list, key=lambda x: x[1])[0]
# all_best['2t_nn_prediction'][-2]
[s for s in stats_list if s[0].step_size == 1e-5]
# Out:
# [(args(step_size=1e-05, epsilon=1.0),
#   0.27036023,
#   array([[0.29788962, 0.27775106, 0.25880617, ..., 0.28746188, 0.33162522,
#           0.16581258],
#          [0.32760417, 0.41153118, 0.37234184, ..., 0.36327934, 0.20247269,
#           0.27912807],
#          [0.264392  , 0.37890106, 0.30763337, ..., 0.28080788, 0.24747871,
#           0.39746556],
#          ...,
#          [0.27284187, 0.27630654, 0.36924455, ..., 0.3432928 , 0.3332931 ,
#           0.25080335],
#          [0.32730085, 0.35114232, 0.3743248 , ..., 0.23663229, 0.28662664,
#           0.24163316],
#          [0.30665952, 0.4144486 , 0.398225  , ..., 0.33662984, 0.18914647,
#           0.30163354]], dtype=float32),
#   [{'po_degree': 0.0,
#     'epsilon_start': 1.0,
#     'buffer_size': 20000,
#     'test_episodes': 5,
#     'p_prefilled': 0.0,
#     'k_rnn_hs': 1,
#     'checkpoint_freq': 0,
#     'distance_noise': False,
#     'weight_init': 'fan_avg',
#     'unnormalized_counts': False,
#     'fixed_gvf_path': None,
#     'max_episode_steps': 200,
#     'epsilon': 1.0,
#     'size': 9,
#     'offline_eval_freq': 0,
#     'step_size': 1e-05,
#     'update_weight_interval': 1,
#     'same_k_rnn_params': False,
#     'v_max': 100,
#     'random_start': True,
#     'discounting': 0.9,
#     'uncertainty_decay': 1.0,
#     'trunc': 10,
#     'test_eps': 0.0,
#     'atoms': 51,
#     'blur_prob': 0.3,
#     'arch': 'nn',
#     'total_steps': 500000,
#     'init_hidden_var': 0.0,
#     'er_hidden_update': None,
#     'env': '2t',
#     'value_step_size': 0.0001,
#     'seed': 2020,
#     'save_all_checkpoints': False,
#     'batch_size': 64,
#     'task_fname': 'task_{}_config.json',
#     'trace_decay': 0.9,
#     'distance_unc_encoding': False,
#     'n_particles': -1,
#     'random_reward_start': False,
#     'action_cond': None,
#     'distributional': False,
#     'replay': False,
#     'view_test_ep': False,
#     'algo': 'sarsa',
#     'count_decay': 1.0,
#     'slip_turn': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'slip_prob': 0.0,
#     'anneal_steps': 0,
#     'save_model': False,
#     'n_hidden': 20,
#     'v_min': -10,
#     'rock_obs_init': 0.0,
#     'resample_interval': 1,
#     'platform': 'cpu',
#     'exploration': 'eps',
#     'half_efficiency_distance': 20.0,
#     'optim': 'adam'},
#    {'test_eps': 0.0,
#     'init_hidden_var': 0.0,
#     'v_max': 100,
#     'count_decay': 1.0,
#     'total_steps': 500000,
#     'distance_unc_encoding': False,
#     'n_particles': -1,
#     'k_rnn_hs': 1,
#     'rock_obs_init': 0.0,
#     'update_weight_interval': 1,
#     'platform': 'cpu',
#     'optim': 'adam',
#     'distance_noise': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'uncertainty_decay': 1.0,
#     'view_test_ep': False,
#     'distributional': False,
#     'seed': 2037,
#     'v_min': -10,
#     'save_model': False,
#     'save_all_checkpoints': False,
#     'er_hidden_update': None,
#     'test_episodes': 5,
#     'p_prefilled': 0.0,
#     'anneal_steps': 0,
#     'trunc': 10,
#     'action_cond': None,
#     'task_fname': 'task_{}_config.json',
#     'replay': False,
#     'exploration': 'eps',
#     'random_start': True,
#     'random_reward_start': False,
#     'n_hidden': 20,
#     'half_efficiency_distance': 20.0,
#     'batch_size': 64,
#     'fixed_gvf_path': None,
#     'blur_prob': 0.3,
#     'value_step_size': 0.0001,
#     'slip_turn': False,
#     'atoms': 51,
#     'slip_prob': 0.0,
#     'discounting': 0.9,
#     'arch': 'nn',
#     'buffer_size': 20000,
#     'checkpoint_freq': 0,
#     'algo': 'sarsa',
#     'weight_init': 'fan_avg',
#     'step_size': 1e-05,
#     'size': 9,
#     'resample_interval': 1,
#     'epsilon_start': 1.0,
#     'epsilon': 1.0,
#     'unnormalized_counts': False,
#     'trace_decay': 0.9,
#     'offline_eval_freq': 0,
#     'po_degree': 0.0,
#     'max_episode_steps': 200,
#     'same_k_rnn_params': False,
#     'env': '2t'},
#    {'buffer_size': 20000,
#     'max_episode_steps': 200,
#     'batch_size': 64,
#     'save_all_checkpoints': False,
#     'resample_interval': 1,
#     'platform': 'cpu',
#     'view_test_ep': False,
#     'rock_obs_init': 0.0,
#     'random_reward_start': False,
#     'trace_decay': 0.9,
#     'distributional': False,
#     'same_k_rnn_params': False,
#     'po_degree': 0.0,
#     'epsilon_start': 1.0,
#     'offline_eval_freq': 0,
#     'p_prefilled': 0.0,
#     'n_hidden': 20,
#     'weight_init': 'fan_avg',
#     'step_size': 1e-05,
#     'value_step_size': 0.0001,
#     'save_model': False,
#     'discounting': 0.9,
#     'unnormalized_counts': False,
#     'v_min': -10,
#     'fixed_gvf_path': None,
#     'env': '2t',
#     'er_hidden_update': None,
#     'blur_prob': 0.3,
#     'epsilon': 1.0,
#     'distance_noise': False,
#     'test_episodes': 5,
#     'init_hidden_var': 0.0,
#     'update_weight_interval': 1,
#     'n_particles': -1,
#     'task_fname': 'task_{}_config.json',
#     'exploration': 'eps',
#     'trunc': 10,
#     'replay': False,
#     'half_efficiency_distance': 20.0,
#     'atoms': 51,
#     'optim': 'adam',
#     'anneal_steps': 0,
#     'slip_turn': False,
#     'distance_unc_encoding': False,
#     'k_rnn_hs': 1,
#     'random_start': True,
#     'slip_prob': 0.0,
#     'count_decay': 1.0,
#     'arch': 'nn',
#     'total_steps': 500000,
#     'size': 9,
#     'test_eps': 0.0,
#     'uncertainty_decay': 1.0,
#     'checkpoint_freq': 0,
#     'v_max': 100,
#     'algo': 'sarsa',
#     'seed': 2027,
#     'action_cond': None,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn')},
#    {'task_fname': 'task_{}_config.json',
#     'save_all_checkpoints': False,
#     'platform': 'cpu',
#     'size': 9,
#     'resample_interval': 1,
#     'blur_prob': 0.3,
#     'uncertainty_decay': 1.0,
#     'slip_turn': False,
#     'action_cond': None,
#     'discounting': 0.9,
#     'v_max': 100,
#     'test_eps': 0.0,
#     'v_min': -10,
#     'rock_obs_init': 0.0,
#     'trace_decay': 0.9,
#     'n_particles': -1,
#     'unnormalized_counts': False,
#     'update_weight_interval': 1,
#     'value_step_size': 0.0001,
#     'env': '2t',
#     'same_k_rnn_params': False,
#     'buffer_size': 20000,
#     'distance_noise': False,
#     'po_degree': 0.0,
#     'epsilon_start': 1.0,
#     'fixed_gvf_path': None,
#     'init_hidden_var': 0.0,
#     'seed': 2023,
#     'distributional': False,
#     'atoms': 51,
#     'results_dir': PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn'),
#     'view_test_ep': False,
#     'save_model': False,
#     'offline_eval_freq': 0,
#     'checkpoint_freq': 0,
#     'p_prefilled': 0.0,
#     'arch': 'nn',
#     'algo': 'sarsa',
#     'er_hidden_update': None,
#     'trunc': 10,
#     'half_efficiency_distance': 20.0,
#     'replay': False,
#     'weight_init': 'fan_avg',
#     'epsilon': 1.0,
#     'distance_unc_encoding': False,
#     'batch_size': 64,
#     'test_episodes': 5,
#     'slip_prob': 0.0,
#     'anneal_steps': 0,
#     'count_decay': 1.0,
#     'random_start': True,
#     'step_size': 1e-05,
#     'exploration': 'eps',
#     'optim': 'adam',
#     'k_rnn_hs': 1,
#     'random_reward_start': False,
#     'total_steps': 500000,
#     'max_episode_steps': 200,
#     'n_hidden': 20},
#    {'resample_interval': 1,
#     'seed': 2040,
#     'exploration': 'eps',
#     'distributional': False,
#     'n_particles': -1,
#     'v_max': 100,
#     'slip_prob': 0.0,
#     'er_hidden_update': None,
#     'atoms': 51,
#     'platform': 'cpu',
#     'half_efficiency_distance': 20.0,
#     'max_episode_steps': 200,
#     'offline_eval_freq': 0,
#     'blur_prob': 0.3,
#     'epsilon_start': 1.0,
#     'checkpoint_freq': 0,
#     'batch_size': 64,
#     'action_cond': None,
#     'unnormalized_counts': False,
#     'task_fname': 'task_{}_config.json',
#     'env': '2t',
#     'k_rnn_hs': 1,
#     'value_step_size': 0.0001,
#     'fixed_gvf_path': None,
#     'view_test_ep': False,
#     'trace_decay': 0.9,
#     'test_episodes': 5,
#     'rock_obs_init': 0.0,
#     'arch': 'nn',
#     'step_size': 1e-05,
#     'v_min': -10,
#     'save_model': False,
#     'update_weight_interval': 1,
#     'size': 9,
#     'same_k_rnn_params': False,
#     'weight_init': 'fan_avg',
#     'p_prefilled': 0.0,
#     'uncertainty_decay': 1.0,
#     'slip_turn': False,
#     'trunc': 10,
#     'epsilon': 1.0,
#     'distance_unc_encoding': False,
#     'random_reward_start': False,
#     'anneal_steps': 0,
#     'distance_noise': False,
#     'discounting': 0.9,
#     'replay': False,
#     'total_steps': 500000,
#     'n_hidden': 20,
#     'random_start': True,
#     'count_decay': 1.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'buffer_size': 20000,
#     'optim': 'adam',
#     'init_hidden_var': 0.0,
#     'po_degree': 0.0,
#     'algo': 'sarsa',
#     'save_all_checkpoints': False,
#     'test_eps': 0.0},
#    {'random_start': True,
#     'max_episode_steps': 200,
#     'n_hidden': 20,
#     'test_eps': 0.0,
#     'exploration': 'eps',
#     'slip_turn': False,
#     'optim': 'adam',
#     'slip_prob': 0.0,
#     'v_max': 100,
#     'save_all_checkpoints': False,
#     'batch_size': 64,
#     'distributional': False,
#     'task_fname': 'task_{}_config.json',
#     'blur_prob': 0.3,
#     'total_steps': 500000,
#     'epsilon': 1.0,
#     'seed': 2021,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'random_reward_start': False,
#     'view_test_ep': False,
#     'trunc': 10,
#     'k_rnn_hs': 1,
#     'fixed_gvf_path': None,
#     'v_min': -10,
#     'value_step_size': 0.0001,
#     'env': '2t',
#     'platform': 'cpu',
#     'offline_eval_freq': 0,
#     'n_particles': -1,
#     'save_model': False,
#     'count_decay': 1.0,
#     'checkpoint_freq': 0,
#     'distance_noise': False,
#     'size': 9,
#     'discounting': 0.9,
#     'init_hidden_var': 0.0,
#     'rock_obs_init': 0.0,
#     'update_weight_interval': 1,
#     'arch': 'nn',
#     'algo': 'sarsa',
#     'uncertainty_decay': 1.0,
#     'action_cond': None,
#     'replay': False,
#     'anneal_steps': 0,
#     'resample_interval': 1,
#     'weight_init': 'fan_avg',
#     'same_k_rnn_params': False,
#     'buffer_size': 20000,
#     'epsilon_start': 1.0,
#     'atoms': 51,
#     'er_hidden_update': None,
#     'trace_decay': 0.9,
#     'distance_unc_encoding': False,
#     'unnormalized_counts': False,
#     'step_size': 1e-05,
#     'po_degree': 0.0,
#     'half_efficiency_distance': 20.0,
#     'p_prefilled': 0.0,
#     'test_episodes': 5},
#    {'action_cond': None,
#     'optim': 'adam',
#     'rock_obs_init': 0.0,
#     'resample_interval': 1,
#     'batch_size': 64,
#     'atoms': 51,
#     'task_fname': 'task_{}_config.json',
#     'er_hidden_update': None,
#     'discounting': 0.9,
#     'view_test_ep': False,
#     'total_steps': 500000,
#     'offline_eval_freq': 0,
#     'checkpoint_freq': 0,
#     'exploration': 'eps',
#     'trunc': 10,
#     'uncertainty_decay': 1.0,
#     'random_reward_start': False,
#     'algo': 'sarsa',
#     'trace_decay': 0.9,
#     'k_rnn_hs': 1,
#     'distance_noise': False,
#     'platform': 'cpu',
#     'arch': 'nn',
#     'n_particles': -1,
#     'buffer_size': 20000,
#     'env': '2t',
#     'epsilon_start': 1.0,
#     'count_decay': 1.0,
#     'blur_prob': 0.3,
#     'half_efficiency_distance': 20.0,
#     'seed': 2047,
#     'distributional': False,
#     'slip_turn': False,
#     'replay': False,
#     'size': 9,
#     'anneal_steps': 0,
#     'init_hidden_var': 0.0,
#     'p_prefilled': 0.0,
#     'v_min': -10,
#     'v_max': 100,
#     'max_episode_steps': 200,
#     'value_step_size': 0.0001,
#     'same_k_rnn_params': False,
#     'distance_unc_encoding': False,
#     'fixed_gvf_path': None,
#     'random_start': True,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'step_size': 1e-05,
#     'test_episodes': 5,
#     'unnormalized_counts': False,
#     'weight_init': 'fan_avg',
#     'n_hidden': 20,
#     'test_eps': 0.0,
#     'save_model': False,
#     'po_degree': 0.0,
#     'save_all_checkpoints': False,
#     'slip_prob': 0.0,
#     'epsilon': 1.0,
#     'update_weight_interval': 1},
#    {'fixed_gvf_path': None,
#     'value_step_size': 0.0001,
#     'replay': False,
#     'total_steps': 500000,
#     'action_cond': None,
#     'po_degree': 0.0,
#     'distance_unc_encoding': False,
#     'k_rnn_hs': 1,
#     'random_start': True,
#     'exploration': 'eps',
#     'blur_prob': 0.3,
#     'resample_interval': 1,
#     'arch': 'nn',
#     'er_hidden_update': None,
#     'optim': 'adam',
#     'update_weight_interval': 1,
#     'epsilon': 1.0,
#     'n_hidden': 20,
#     'unnormalized_counts': False,
#     'n_particles': -1,
#     'env': '2t',
#     'rock_obs_init': 0.0,
#     'buffer_size': 20000,
#     'platform': 'cpu',
#     'slip_turn': False,
#     'offline_eval_freq': 0,
#     'slip_prob': 0.0,
#     'algo': 'sarsa',
#     'v_max': 100,
#     'uncertainty_decay': 1.0,
#     'discounting': 0.9,
#     'half_efficiency_distance': 20.0,
#     'weight_init': 'fan_avg',
#     'checkpoint_freq': 0,
#     'seed': 2028,
#     'atoms': 51,
#     'anneal_steps': 0,
#     'trace_decay': 0.9,
#     'test_episodes': 5,
#     'epsilon_start': 1.0,
#     'batch_size': 64,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'task_fname': 'task_{}_config.json',
#     'count_decay': 1.0,
#     'view_test_ep': False,
#     'trunc': 10,
#     'same_k_rnn_params': False,
#     'v_min': -10,
#     'max_episode_steps': 200,
#     'save_model': False,
#     'distributional': False,
#     'save_all_checkpoints': False,
#     'distance_noise': False,
#     'init_hidden_var': 0.0,
#     'p_prefilled': 0.0,
#     'random_reward_start': False,
#     'size': 9,
#     'test_eps': 0.0,
#     'step_size': 1e-05},
#    {'rock_obs_init': 0.0,
#     'p_prefilled': 0.0,
#     'slip_turn': False,
#     'random_reward_start': False,
#     'er_hidden_update': None,
#     'atoms': 51,
#     'slip_prob': 0.0,
#     'epsilon_start': 1.0,
#     'total_steps': 500000,
#     'value_step_size': 0.0001,
#     'save_model': False,
#     'batch_size': 64,
#     'epsilon': 1.0,
#     'fixed_gvf_path': None,
#     'offline_eval_freq': 0,
#     'same_k_rnn_params': False,
#     'init_hidden_var': 0.0,
#     'count_decay': 1.0,
#     'distance_unc_encoding': False,
#     'test_eps': 0.0,
#     'trunc': 10,
#     'k_rnn_hs': 1,
#     'seed': 2041,
#     'n_hidden': 20,
#     'resample_interval': 1,
#     'random_start': True,
#     'v_max': 100,
#     'trace_decay': 0.9,
#     'buffer_size': 20000,
#     'discounting': 0.9,
#     'anneal_steps': 0,
#     'blur_prob': 0.3,
#     'uncertainty_decay': 1.0,
#     'unnormalized_counts': False,
#     'optim': 'adam',
#     'action_cond': None,
#     'exploration': 'eps',
#     'size': 9,
#     'v_min': -10,
#     'task_fname': 'task_{}_config.json',
#     'max_episode_steps': 200,
#     'po_degree': 0.0,
#     'env': '2t',
#     'half_efficiency_distance': 20.0,
#     'checkpoint_freq': 0,
#     'platform': 'cpu',
#     'arch': 'nn',
#     'n_particles': -1,
#     'weight_init': 'fan_avg',
#     'distance_noise': False,
#     'step_size': 1e-05,
#     'save_all_checkpoints': False,
#     'distributional': False,
#     'update_weight_interval': 1,
#     'test_episodes': 5,
#     'view_test_ep': False,
#     'algo': 'sarsa',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'replay': False},
#    {'weight_init': 'fan_avg',
#     'value_step_size': 0.0001,
#     'anneal_steps': 0,
#     'n_particles': -1,
#     'er_hidden_update': None,
#     'discounting': 0.9,
#     'random_reward_start': False,
#     'blur_prob': 0.3,
#     'trunc': 10,
#     'epsilon_start': 1.0,
#     'checkpoint_freq': 0,
#     'same_k_rnn_params': False,
#     'save_all_checkpoints': False,
#     'distance_noise': False,
#     'v_min': -10,
#     'p_prefilled': 0.0,
#     'offline_eval_freq': 0,
#     'rock_obs_init': 0.0,
#     'optim': 'adam',
#     'half_efficiency_distance': 20.0,
#     'init_hidden_var': 0.0,
#     'arch': 'nn',
#     'buffer_size': 20000,
#     'algo': 'sarsa',
#     'seed': 2032,
#     'task_fname': 'task_{}_config.json',
#     'po_degree': 0.0,
#     'slip_turn': False,
#     'view_test_ep': False,
#     'slip_prob': 0.0,
#     'random_start': True,
#     'max_episode_steps': 200,
#     'step_size': 1e-05,
#     'resample_interval': 1,
#     'unnormalized_counts': False,
#     'size': 9,
#     'test_eps': 0.0,
#     'action_cond': None,
#     'save_model': False,
#     'test_episodes': 5,
#     'atoms': 51,
#     'count_decay': 1.0,
#     'n_hidden': 20,
#     'uncertainty_decay': 1.0,
#     'distance_unc_encoding': False,
#     'total_steps': 500000,
#     'update_weight_interval': 1,
#     'exploration': 'eps',
#     'v_max': 100,
#     'batch_size': 64,
#     'env': '2t',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'platform': 'cpu',
#     'replay': False,
#     'distributional': False,
#     'trace_decay': 0.9,
#     'k_rnn_hs': 1,
#     'epsilon': 1.0,
#     'fixed_gvf_path': None},
#    {'uncertainty_decay': 1.0,
#     'action_cond': None,
#     'v_min': -10,
#     'rock_obs_init': 0.0,
#     'blur_prob': 0.3,
#     'epsilon': 1.0,
#     'save_model': False,
#     'slip_turn': False,
#     'buffer_size': 20000,
#     'trace_decay': 0.9,
#     'seed': 2030,
#     'step_size': 1e-05,
#     'count_decay': 1.0,
#     'optim': 'adam',
#     'test_eps': 0.0,
#     'arch': 'nn',
#     'n_particles': -1,
#     'random_start': True,
#     'p_prefilled': 0.0,
#     'max_episode_steps': 200,
#     'random_reward_start': False,
#     'trunc': 10,
#     'v_max': 100,
#     'task_fname': 'task_{}_config.json',
#     'algo': 'sarsa',
#     'k_rnn_hs': 1,
#     'size': 9,
#     'distributional': False,
#     'batch_size': 64,
#     'atoms': 51,
#     'replay': False,
#     'half_efficiency_distance': 20.0,
#     'distance_noise': False,
#     'init_hidden_var': 0.0,
#     'offline_eval_freq': 0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'test_episodes': 5,
#     'value_step_size': 0.0001,
#     'epsilon_start': 1.0,
#     'unnormalized_counts': False,
#     'total_steps': 500000,
#     'resample_interval': 1,
#     'anneal_steps': 0,
#     'env': '2t',
#     'distance_unc_encoding': False,
#     'fixed_gvf_path': None,
#     'weight_init': 'fan_avg',
#     'update_weight_interval': 1,
#     'save_all_checkpoints': False,
#     'checkpoint_freq': 0,
#     'same_k_rnn_params': False,
#     'exploration': 'eps',
#     'discounting': 0.9,
#     'view_test_ep': False,
#     'platform': 'cpu',
#     'po_degree': 0.0,
#     'n_hidden': 20,
#     'slip_prob': 0.0,
#     'er_hidden_update': None},
#    {'trace_decay': 0.9,
#     'total_steps': 500000,
#     'count_decay': 1.0,
#     'epsilon': 1.0,
#     'platform': 'cpu',
#     'save_all_checkpoints': False,
#     'optim': 'adam',
#     'random_start': True,
#     'env': '2t',
#     'same_k_rnn_params': False,
#     'slip_turn': False,
#     'batch_size': 64,
#     'k_rnn_hs': 1,
#     'er_hidden_update': None,
#     'rock_obs_init': 0.0,
#     'n_hidden': 20,
#     'po_degree': 0.0,
#     'update_weight_interval': 1,
#     'unnormalized_counts': False,
#     'fixed_gvf_path': None,
#     'blur_prob': 0.3,
#     'buffer_size': 20000,
#     'value_step_size': 0.0001,
#     'save_model': False,
#     'action_cond': None,
#     'step_size': 1e-05,
#     'view_test_ep': False,
#     'slip_prob': 0.0,
#     'epsilon_start': 1.0,
#     'arch': 'nn',
#     'p_prefilled': 0.0,
#     'distance_noise': False,
#     'init_hidden_var': 0.0,
#     'uncertainty_decay': 1.0,
#     'distributional': False,
#     'n_particles': -1,
#     'atoms': 51,
#     'resample_interval': 1,
#     'size': 9,
#     'test_eps': 0.0,
#     'half_efficiency_distance': 20.0,
#     'max_episode_steps': 200,
#     'weight_init': 'fan_avg',
#     'anneal_steps': 0,
#     'v_max': 100,
#     'random_reward_start': False,
#     'trunc': 10,
#     'test_episodes': 5,
#     'seed': 2044,
#     'exploration': 'eps',
#     'distance_unc_encoding': False,
#     'algo': 'sarsa',
#     'discounting': 0.9,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'checkpoint_freq': 0,
#     'offline_eval_freq': 0,
#     'task_fname': 'task_{}_config.json',
#     'replay': False,
#     'v_min': -10},
#    {'replay': False,
#     'random_start': True,
#     'save_model': False,
#     'view_test_ep': False,
#     'update_weight_interval': 1,
#     'rock_obs_init': 0.0,
#     'half_efficiency_distance': 20.0,
#     'slip_prob': 0.0,
#     'random_reward_start': False,
#     'p_prefilled': 0.0,
#     'n_particles': -1,
#     'total_steps': 500000,
#     'algo': 'sarsa',
#     'k_rnn_hs': 1,
#     'test_eps': 0.0,
#     'value_step_size': 0.0001,
#     'epsilon': 1.0,
#     'v_min': -10,
#     'max_episode_steps': 200,
#     'env': '2t',
#     'distance_unc_encoding': False,
#     'init_hidden_var': 0.0,
#     'epsilon_start': 1.0,
#     'er_hidden_update': None,
#     'same_k_rnn_params': False,
#     'optim': 'adam',
#     'checkpoint_freq': 0,
#     'n_hidden': 20,
#     'batch_size': 64,
#     'atoms': 51,
#     'anneal_steps': 0,
#     'offline_eval_freq': 0,
#     'count_decay': 1.0,
#     'po_degree': 0.0,
#     'distance_noise': False,
#     'seed': 2049,
#     'fixed_gvf_path': None,
#     'resample_interval': 1,
#     'task_fname': 'task_{}_config.json',
#     'save_all_checkpoints': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'v_max': 100,
#     'unnormalized_counts': False,
#     'size': 9,
#     'exploration': 'eps',
#     'step_size': 1e-05,
#     'arch': 'nn',
#     'weight_init': 'fan_avg',
#     'action_cond': None,
#     'discounting': 0.9,
#     'platform': 'cpu',
#     'trunc': 10,
#     'trace_decay': 0.9,
#     'slip_turn': False,
#     'distributional': False,
#     'test_episodes': 5,
#     'buffer_size': 20000,
#     'blur_prob': 0.3,
#     'uncertainty_decay': 1.0},
#    {'step_size': 1e-05,
#     'blur_prob': 0.3,
#     'batch_size': 64,
#     'seed': 2024,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'distance_noise': False,
#     'po_degree': 0.0,
#     'algo': 'sarsa',
#     'save_model': False,
#     'value_step_size': 0.0001,
#     'v_max': 100,
#     'n_particles': -1,
#     'epsilon_start': 1.0,
#     'random_start': True,
#     'action_cond': None,
#     'unnormalized_counts': False,
#     'test_eps': 0.0,
#     'fixed_gvf_path': None,
#     'trace_decay': 0.9,
#     'buffer_size': 20000,
#     'epsilon': 1.0,
#     'discounting': 0.9,
#     'platform': 'cpu',
#     'atoms': 51,
#     'task_fname': 'task_{}_config.json',
#     'anneal_steps': 0,
#     'distance_unc_encoding': False,
#     'k_rnn_hs': 1,
#     'half_efficiency_distance': 20.0,
#     'v_min': -10,
#     'random_reward_start': False,
#     'exploration': 'eps',
#     'rock_obs_init': 0.0,
#     'optim': 'adam',
#     'n_hidden': 20,
#     'init_hidden_var': 0.0,
#     'count_decay': 1.0,
#     'slip_prob': 0.0,
#     'replay': False,
#     'size': 9,
#     'trunc': 10,
#     'update_weight_interval': 1,
#     'same_k_rnn_params': False,
#     'checkpoint_freq': 0,
#     'max_episode_steps': 200,
#     'offline_eval_freq': 0,
#     'weight_init': 'fan_avg',
#     'view_test_ep': False,
#     'resample_interval': 1,
#     'er_hidden_update': None,
#     'p_prefilled': 0.0,
#     'env': '2t',
#     'arch': 'nn',
#     'total_steps': 500000,
#     'save_all_checkpoints': False,
#     'test_episodes': 5,
#     'distributional': False,
#     'uncertainty_decay': 1.0,
#     'slip_turn': False},
#    {'half_efficiency_distance': 20.0,
#     'algo': 'sarsa',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'platform': 'cpu',
#     'same_k_rnn_params': False,
#     'slip_turn': False,
#     'trace_decay': 0.9,
#     'step_size': 1e-05,
#     'k_rnn_hs': 1,
#     'er_hidden_update': None,
#     'v_max': 100,
#     'view_test_ep': False,
#     'v_min': -10,
#     'optim': 'adam',
#     'epsilon_start': 1.0,
#     'env': '2t',
#     'count_decay': 1.0,
#     'arch': 'nn',
#     'distance_unc_encoding': False,
#     'trunc': 10,
#     'atoms': 51,
#     'slip_prob': 0.0,
#     'distributional': False,
#     'p_prefilled': 0.0,
#     'rock_obs_init': 0.0,
#     'po_degree': 0.0,
#     'n_particles': -1,
#     'fixed_gvf_path': None,
#     'batch_size': 64,
#     'init_hidden_var': 0.0,
#     'value_step_size': 0.0001,
#     'update_weight_interval': 1,
#     'seed': 2034,
#     'blur_prob': 0.3,
#     'random_reward_start': False,
#     'max_episode_steps': 200,
#     'offline_eval_freq': 0,
#     'total_steps': 500000,
#     'action_cond': None,
#     'save_model': False,
#     'random_start': True,
#     'uncertainty_decay': 1.0,
#     'n_hidden': 20,
#     'anneal_steps': 0,
#     'task_fname': 'task_{}_config.json',
#     'test_episodes': 5,
#     'discounting': 0.9,
#     'exploration': 'eps',
#     'save_all_checkpoints': False,
#     'epsilon': 1.0,
#     'weight_init': 'fan_avg',
#     'checkpoint_freq': 0,
#     'distance_noise': False,
#     'size': 9,
#     'unnormalized_counts': False,
#     'buffer_size': 20000,
#     'replay': False,
#     'test_eps': 0.0,
#     'resample_interval': 1},
#    {'slip_prob': 0.0,
#     'arch': 'nn',
#     'optim': 'adam',
#     'blur_prob': 0.3,
#     'trunc': 10,
#     'rock_obs_init': 0.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'discounting': 0.9,
#     'n_particles': -1,
#     'anneal_steps': 0,
#     'epsilon': 1.0,
#     'po_degree': 0.0,
#     'uncertainty_decay': 1.0,
#     'trace_decay': 0.9,
#     'distributional': False,
#     'k_rnn_hs': 1,
#     'n_hidden': 20,
#     'offline_eval_freq': 0,
#     'update_weight_interval': 1,
#     'same_k_rnn_params': False,
#     'count_decay': 1.0,
#     'test_episodes': 5,
#     'slip_turn': False,
#     'weight_init': 'fan_avg',
#     'algo': 'sarsa',
#     'atoms': 51,
#     'unnormalized_counts': False,
#     'seed': 2031,
#     'action_cond': None,
#     'step_size': 1e-05,
#     'save_all_checkpoints': False,
#     'v_max': 100,
#     'v_min': -10,
#     'replay': False,
#     'resample_interval': 1,
#     'distance_noise': False,
#     'exploration': 'eps',
#     'checkpoint_freq': 0,
#     'batch_size': 64,
#     'init_hidden_var': 0.0,
#     'random_start': True,
#     'buffer_size': 20000,
#     'er_hidden_update': None,
#     'task_fname': 'task_{}_config.json',
#     'total_steps': 500000,
#     'random_reward_start': False,
#     'distance_unc_encoding': False,
#     'p_prefilled': 0.0,
#     'size': 9,
#     'max_episode_steps': 200,
#     'fixed_gvf_path': None,
#     'value_step_size': 0.0001,
#     'platform': 'cpu',
#     'half_efficiency_distance': 20.0,
#     'epsilon_start': 1.0,
#     'env': '2t',
#     'test_eps': 0.0,
#     'view_test_ep': False,
#     'save_model': False},
#    {'half_efficiency_distance': 20.0,
#     'discounting': 0.9,
#     'seed': 2025,
#     'checkpoint_freq': 0,
#     'view_test_ep': False,
#     'arch': 'nn',
#     'test_episodes': 5,
#     'random_reward_start': False,
#     'save_all_checkpoints': False,
#     'random_start': True,
#     'save_model': False,
#     'distributional': False,
#     'platform': 'cpu',
#     'uncertainty_decay': 1.0,
#     'update_weight_interval': 1,
#     'env': '2t',
#     'test_eps': 0.0,
#     'slip_prob': 0.0,
#     'anneal_steps': 0,
#     'max_episode_steps': 200,
#     'init_hidden_var': 0.0,
#     'atoms': 51,
#     'weight_init': 'fan_avg',
#     'slip_turn': False,
#     'epsilon': 1.0,
#     'n_hidden': 20,
#     'blur_prob': 0.3,
#     'v_max': 100,
#     'n_particles': -1,
#     'distance_unc_encoding': False,
#     'rock_obs_init': 0.0,
#     'fixed_gvf_path': None,
#     'action_cond': None,
#     'value_step_size': 0.0001,
#     'size': 9,
#     'distance_noise': False,
#     'count_decay': 1.0,
#     'algo': 'sarsa',
#     'total_steps': 500000,
#     'step_size': 1e-05,
#     'batch_size': 64,
#     'v_min': -10,
#     'epsilon_start': 1.0,
#     'trunc': 10,
#     'replay': False,
#     'k_rnn_hs': 1,
#     'buffer_size': 20000,
#     'offline_eval_freq': 0,
#     'er_hidden_update': None,
#     'exploration': 'eps',
#     'same_k_rnn_params': False,
#     'resample_interval': 1,
#     'p_prefilled': 0.0,
#     'optim': 'adam',
#     'task_fname': 'task_{}_config.json',
#     'po_degree': 0.0,
#     'unnormalized_counts': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'trace_decay': 0.9},
#    {'distance_noise': False,
#     'arch': 'nn',
#     'v_min': -10,
#     'count_decay': 1.0,
#     'test_episodes': 5,
#     'checkpoint_freq': 0,
#     'epsilon': 1.0,
#     'slip_turn': False,
#     'n_hidden': 20,
#     'weight_init': 'fan_avg',
#     'fixed_gvf_path': None,
#     'po_degree': 0.0,
#     'half_efficiency_distance': 20.0,
#     'n_particles': -1,
#     'test_eps': 0.0,
#     'seed': 2045,
#     'random_reward_start': False,
#     'exploration': 'eps',
#     'k_rnn_hs': 1,
#     'algo': 'sarsa',
#     'unnormalized_counts': False,
#     'size': 9,
#     'buffer_size': 20000,
#     'save_all_checkpoints': False,
#     'slip_prob': 0.0,
#     'platform': 'cpu',
#     'offline_eval_freq': 0,
#     'trace_decay': 0.9,
#     'rock_obs_init': 0.0,
#     'atoms': 51,
#     'init_hidden_var': 0.0,
#     'same_k_rnn_params': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'trunc': 10,
#     'update_weight_interval': 1,
#     'blur_prob': 0.3,
#     'v_max': 100,
#     'max_episode_steps': 200,
#     'resample_interval': 1,
#     'anneal_steps': 0,
#     'env': '2t',
#     'value_step_size': 0.0001,
#     'p_prefilled': 0.0,
#     'uncertainty_decay': 1.0,
#     'distance_unc_encoding': False,
#     'distributional': False,
#     'random_start': True,
#     'optim': 'adam',
#     'batch_size': 64,
#     'discounting': 0.9,
#     'epsilon_start': 1.0,
#     'replay': False,
#     'action_cond': None,
#     'total_steps': 500000,
#     'view_test_ep': False,
#     'er_hidden_update': None,
#     'save_model': False,
#     'step_size': 1e-05,
#     'task_fname': 'task_{}_config.json'},
#    {'v_min': -10,
#     'save_all_checkpoints': False,
#     'weight_init': 'fan_avg',
#     'blur_prob': 0.3,
#     'distributional': False,
#     'fixed_gvf_path': None,
#     'checkpoint_freq': 0,
#     'test_eps': 0.0,
#     'random_start': True,
#     'total_steps': 500000,
#     'k_rnn_hs': 1,
#     'half_efficiency_distance': 20.0,
#     'value_step_size': 0.0001,
#     'discounting': 0.9,
#     'same_k_rnn_params': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'init_hidden_var': 0.0,
#     'seed': 2036,
#     'task_fname': 'task_{}_config.json',
#     'distance_unc_encoding': False,
#     'uncertainty_decay': 1.0,
#     'v_max': 100,
#     'rock_obs_init': 0.0,
#     'n_hidden': 20,
#     'offline_eval_freq': 0,
#     'replay': False,
#     'env': '2t',
#     'random_reward_start': False,
#     'max_episode_steps': 200,
#     'size': 9,
#     'count_decay': 1.0,
#     'action_cond': None,
#     'er_hidden_update': None,
#     'slip_prob': 0.0,
#     'test_episodes': 5,
#     'exploration': 'eps',
#     'resample_interval': 1,
#     'epsilon_start': 1.0,
#     'unnormalized_counts': False,
#     'platform': 'cpu',
#     'p_prefilled': 0.0,
#     'buffer_size': 20000,
#     'save_model': False,
#     'po_degree': 0.0,
#     'view_test_ep': False,
#     'optim': 'adam',
#     'epsilon': 1.0,
#     'anneal_steps': 0,
#     'batch_size': 64,
#     'trunc': 10,
#     'algo': 'sarsa',
#     'slip_turn': False,
#     'atoms': 51,
#     'n_particles': -1,
#     'distance_noise': False,
#     'trace_decay': 0.9,
#     'step_size': 1e-05,
#     'update_weight_interval': 1,
#     'arch': 'nn'},
#    {'rock_obs_init': 0.0,
#     'n_hidden': 20,
#     'slip_turn': False,
#     'trunc': 10,
#     'random_reward_start': False,
#     'er_hidden_update': None,
#     'random_start': True,
#     'init_hidden_var': 0.0,
#     'fixed_gvf_path': None,
#     'uncertainty_decay': 1.0,
#     'seed': 2048,
#     'step_size': 1e-05,
#     'unnormalized_counts': False,
#     'trace_decay': 0.9,
#     'action_cond': None,
#     'batch_size': 64,
#     'arch': 'nn',
#     'checkpoint_freq': 0,
#     'resample_interval': 1,
#     'weight_init': 'fan_avg',
#     'algo': 'sarsa',
#     'k_rnn_hs': 1,
#     'task_fname': 'task_{}_config.json',
#     'update_weight_interval': 1,
#     'view_test_ep': False,
#     'save_all_checkpoints': False,
#     'test_eps': 0.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'offline_eval_freq': 0,
#     'platform': 'cpu',
#     'value_step_size': 0.0001,
#     'v_max': 100,
#     'exploration': 'eps',
#     'v_min': -10,
#     'epsilon': 1.0,
#     'p_prefilled': 0.0,
#     'po_degree': 0.0,
#     'n_particles': -1,
#     'count_decay': 1.0,
#     'distance_unc_encoding': False,
#     'atoms': 51,
#     'half_efficiency_distance': 20.0,
#     'anneal_steps': 0,
#     'discounting': 0.9,
#     'buffer_size': 20000,
#     'same_k_rnn_params': False,
#     'test_episodes': 5,
#     'max_episode_steps': 200,
#     'optim': 'adam',
#     'epsilon_start': 1.0,
#     'blur_prob': 0.3,
#     'env': '2t',
#     'replay': False,
#     'slip_prob': 0.0,
#     'save_model': False,
#     'size': 9,
#     'distance_noise': False,
#     'distributional': False,
#     'total_steps': 500000},
#    {'replay': False,
#     'step_size': 1e-05,
#     'epsilon': 1.0,
#     'platform': 'cpu',
#     'trunc': 10,
#     'save_model': False,
#     'random_reward_start': False,
#     'test_eps': 0.0,
#     'p_prefilled': 0.0,
#     'arch': 'nn',
#     'trace_decay': 0.9,
#     'count_decay': 1.0,
#     'v_min': -10,
#     'k_rnn_hs': 1,
#     'max_episode_steps': 200,
#     'unnormalized_counts': False,
#     'anneal_steps': 0,
#     'total_steps': 500000,
#     'algo': 'sarsa',
#     'offline_eval_freq': 0,
#     'action_cond': None,
#     'seed': 2042,
#     'checkpoint_freq': 0,
#     'batch_size': 64,
#     'slip_turn': False,
#     'discounting': 0.9,
#     'atoms': 51,
#     'same_k_rnn_params': False,
#     'er_hidden_update': None,
#     'env': '2t',
#     'distance_unc_encoding': False,
#     'blur_prob': 0.3,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'distance_noise': False,
#     'epsilon_start': 1.0,
#     'resample_interval': 1,
#     'exploration': 'eps',
#     'task_fname': 'task_{}_config.json',
#     'po_degree': 0.0,
#     'slip_prob': 0.0,
#     'save_all_checkpoints': False,
#     'buffer_size': 20000,
#     'optim': 'adam',
#     'fixed_gvf_path': None,
#     'half_efficiency_distance': 20.0,
#     'n_particles': -1,
#     'rock_obs_init': 0.0,
#     'n_hidden': 20,
#     'view_test_ep': False,
#     'random_start': True,
#     'value_step_size': 0.0001,
#     'distributional': False,
#     'update_weight_interval': 1,
#     'test_episodes': 5,
#     'v_max': 100,
#     'uncertainty_decay': 1.0,
#     'size': 9,
#     'init_hidden_var': 0.0,
#     'weight_init': 'fan_avg'},
#    {'slip_prob': 0.0,
#     'replay': False,
#     'distance_unc_encoding': False,
#     'er_hidden_update': None,
#     'random_start': True,
#     'unnormalized_counts': False,
#     'checkpoint_freq': 0,
#     'uncertainty_decay': 1.0,
#     'task_fname': 'task_{}_config.json',
#     'total_steps': 500000,
#     'p_prefilled': 0.0,
#     'v_max': 100,
#     'env': '2t',
#     'platform': 'cpu',
#     'optim': 'adam',
#     'atoms': 51,
#     'trace_decay': 0.9,
#     'anneal_steps': 0,
#     'update_weight_interval': 1,
#     'discounting': 0.9,
#     'distributional': False,
#     'save_all_checkpoints': False,
#     'save_model': False,
#     'weight_init': 'fan_avg',
#     'max_episode_steps': 200,
#     'test_eps': 0.0,
#     'blur_prob': 0.3,
#     'epsilon_start': 1.0,
#     'offline_eval_freq': 0,
#     'distance_noise': False,
#     'same_k_rnn_params': False,
#     'batch_size': 64,
#     'random_reward_start': False,
#     'action_cond': None,
#     'buffer_size': 20000,
#     'count_decay': 1.0,
#     'rock_obs_init': 0.0,
#     'step_size': 1e-05,
#     'n_particles': -1,
#     'po_degree': 0.0,
#     'slip_turn': False,
#     'value_step_size': 0.0001,
#     'exploration': 'eps',
#     'k_rnn_hs': 1,
#     'algo': 'sarsa',
#     'arch': 'nn',
#     'n_hidden': 20,
#     'fixed_gvf_path': None,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'v_min': -10,
#     'resample_interval': 1,
#     'init_hidden_var': 0.0,
#     'view_test_ep': False,
#     'half_efficiency_distance': 20.0,
#     'trunc': 10,
#     'epsilon': 1.0,
#     'test_episodes': 5,
#     'seed': 2035,
#     'size': 9},
#    {'unnormalized_counts': False,
#     'fixed_gvf_path': None,
#     'uncertainty_decay': 1.0,
#     'slip_turn': False,
#     'v_min': -10,
#     'random_reward_start': False,
#     'distributional': False,
#     'trunc': 10,
#     'checkpoint_freq': 0,
#     'po_degree': 0.0,
#     'random_start': True,
#     'size': 9,
#     'epsilon': 1.0,
#     'save_model': False,
#     'atoms': 51,
#     'er_hidden_update': None,
#     'test_episodes': 5,
#     'save_all_checkpoints': False,
#     'epsilon_start': 1.0,
#     'test_eps': 0.0,
#     'exploration': 'eps',
#     'distance_noise': False,
#     'task_fname': 'task_{}_config.json',
#     'slip_prob': 0.0,
#     'batch_size': 64,
#     'blur_prob': 0.3,
#     'distance_unc_encoding': False,
#     'same_k_rnn_params': False,
#     'anneal_steps': 0,
#     'max_episode_steps': 200,
#     'n_hidden': 20,
#     'arch': 'nn',
#     'discounting': 0.9,
#     'seed': 2022,
#     'value_step_size': 0.0001,
#     'platform': 'cpu',
#     'trace_decay': 0.9,
#     'optim': 'adam',
#     'replay': False,
#     'action_cond': None,
#     'half_efficiency_distance': 20.0,
#     'total_steps': 500000,
#     'p_prefilled': 0.0,
#     'init_hidden_var': 0.0,
#     'resample_interval': 1,
#     'rock_obs_init': 0.0,
#     'offline_eval_freq': 0,
#     'view_test_ep': False,
#     'n_particles': -1,
#     'count_decay': 1.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'v_max': 100,
#     'algo': 'sarsa',
#     'update_weight_interval': 1,
#     'env': '2t',
#     'step_size': 1e-05,
#     'weight_init': 'fan_avg',
#     'buffer_size': 20000,
#     'k_rnn_hs': 1},
#    {'slip_turn': False,
#     'exploration': 'eps',
#     'task_fname': 'task_{}_config.json',
#     'discounting': 0.9,
#     'arch': 'nn',
#     'value_step_size': 0.0001,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'weight_init': 'fan_avg',
#     'count_decay': 1.0,
#     'v_max': 100,
#     'distance_noise': False,
#     'seed': 2033,
#     'optim': 'adam',
#     'save_all_checkpoints': False,
#     'rock_obs_init': 0.0,
#     'random_reward_start': False,
#     'anneal_steps': 0,
#     'action_cond': None,
#     'test_episodes': 5,
#     'test_eps': 0.0,
#     'total_steps': 500000,
#     'p_prefilled': 0.0,
#     'offline_eval_freq': 0,
#     'po_degree': 0.0,
#     'atoms': 51,
#     'unnormalized_counts': False,
#     'k_rnn_hs': 1,
#     'er_hidden_update': None,
#     'replay': False,
#     'trunc': 10,
#     'checkpoint_freq': 0,
#     'resample_interval': 1,
#     'epsilon_start': 1.0,
#     'step_size': 1e-05,
#     'n_particles': -1,
#     'view_test_ep': False,
#     'algo': 'sarsa',
#     'platform': 'cpu',
#     'same_k_rnn_params': False,
#     'half_efficiency_distance': 20.0,
#     'fixed_gvf_path': None,
#     'batch_size': 64,
#     'init_hidden_var': 0.0,
#     'v_min': -10,
#     'distance_unc_encoding': False,
#     'epsilon': 1.0,
#     'buffer_size': 20000,
#     'blur_prob': 0.3,
#     'uncertainty_decay': 1.0,
#     'random_start': True,
#     'n_hidden': 20,
#     'distributional': False,
#     'slip_prob': 0.0,
#     'update_weight_interval': 1,
#     'env': '2t',
#     'size': 9,
#     'max_episode_steps': 200,
#     'save_model': False,
#     'trace_decay': 0.9},
#    {'atoms': 51,
#     'view_test_ep': False,
#     'distance_unc_encoding': False,
#     'fixed_gvf_path': None,
#     'init_hidden_var': 0.0,
#     'v_max': 100,
#     'p_prefilled': 0.0,
#     'platform': 'cpu',
#     'n_hidden': 20,
#     'k_rnn_hs': 1,
#     'save_model': False,
#     'half_efficiency_distance': 20.0,
#     'exploration': 'eps',
#     'n_particles': -1,
#     'test_episodes': 5,
#     'unnormalized_counts': False,
#     'size': 9,
#     'slip_turn': False,
#     'v_min': -10,
#     'algo': 'sarsa',
#     'trace_decay': 0.9,
#     'test_eps': 0.0,
#     'weight_init': 'fan_avg',
#     'trunc': 10,
#     'anneal_steps': 0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'discounting': 0.9,
#     'epsilon': 1.0,
#     'checkpoint_freq': 0,
#     'arch': 'nn',
#     'resample_interval': 1,
#     'random_reward_start': False,
#     'update_weight_interval': 1,
#     'seed': 2026,
#     'same_k_rnn_params': False,
#     'task_fname': 'task_{}_config.json',
#     'buffer_size': 20000,
#     'max_episode_steps': 200,
#     'er_hidden_update': None,
#     'step_size': 1e-05,
#     'epsilon_start': 1.0,
#     'action_cond': None,
#     'optim': 'adam',
#     'count_decay': 1.0,
#     'batch_size': 64,
#     'total_steps': 500000,
#     'value_step_size': 0.0001,
#     'distance_noise': False,
#     'uncertainty_decay': 1.0,
#     'blur_prob': 0.3,
#     'save_all_checkpoints': False,
#     'rock_obs_init': 0.0,
#     'offline_eval_freq': 0,
#     'distributional': False,
#     'replay': False,
#     'env': '2t',
#     'po_degree': 0.0,
#     'random_start': True,
#     'slip_prob': 0.0},
#    {'checkpoint_freq': 0,
#     'test_eps': 0.0,
#     'batch_size': 64,
#     'action_cond': None,
#     'replay': False,
#     'view_test_ep': False,
#     'unnormalized_counts': False,
#     'size': 9,
#     'slip_turn': False,
#     'buffer_size': 20000,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'discounting': 0.9,
#     'trunc': 10,
#     'update_weight_interval': 1,
#     'p_prefilled': 0.0,
#     'po_degree': 0.0,
#     'k_rnn_hs': 1,
#     'v_min': -10,
#     'distributional': False,
#     'half_efficiency_distance': 20.0,
#     'uncertainty_decay': 1.0,
#     'count_decay': 1.0,
#     'optim': 'adam',
#     'seed': 2029,
#     'n_hidden': 20,
#     'distance_unc_encoding': False,
#     'epsilon_start': 1.0,
#     'save_model': False,
#     'value_step_size': 0.0001,
#     'atoms': 51,
#     'save_all_checkpoints': False,
#     'total_steps': 500000,
#     'test_episodes': 5,
#     'exploration': 'eps',
#     'epsilon': 1.0,
#     'algo': 'sarsa',
#     'random_reward_start': False,
#     'offline_eval_freq': 0,
#     'env': '2t',
#     'init_hidden_var': 0.0,
#     'fixed_gvf_path': None,
#     'platform': 'cpu',
#     'distance_noise': False,
#     'trace_decay': 0.9,
#     'n_particles': -1,
#     'blur_prob': 0.3,
#     'resample_interval': 1,
#     'v_max': 100,
#     'step_size': 1e-05,
#     'weight_init': 'fan_avg',
#     'same_k_rnn_params': False,
#     'task_fname': 'task_{}_config.json',
#     'rock_obs_init': 0.0,
#     'anneal_steps': 0,
#     'random_start': True,
#     'arch': 'nn',
#     'er_hidden_update': None,
#     'slip_prob': 0.0,
#     'max_episode_steps': 200},
#    {'v_min': -10,
#     'total_steps': 500000,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'seed': 2038,
#     'batch_size': 64,
#     'init_hidden_var': 0.0,
#     'platform': 'cpu',
#     'slip_prob': 0.0,
#     'max_episode_steps': 200,
#     'offline_eval_freq': 0,
#     'unnormalized_counts': False,
#     'update_weight_interval': 1,
#     'resample_interval': 1,
#     'optim': 'adam',
#     'slip_turn': False,
#     'replay': False,
#     'fixed_gvf_path': None,
#     'algo': 'sarsa',
#     'n_particles': -1,
#     'random_start': True,
#     'same_k_rnn_params': False,
#     'env': '2t',
#     'k_rnn_hs': 1,
#     'view_test_ep': False,
#     'distributional': False,
#     'arch': 'nn',
#     'epsilon': 1.0,
#     'step_size': 1e-05,
#     'po_degree': 0.0,
#     'save_all_checkpoints': False,
#     'rock_obs_init': 0.0,
#     'test_episodes': 5,
#     'test_eps': 0.0,
#     'uncertainty_decay': 1.0,
#     'half_efficiency_distance': 20.0,
#     'task_fname': 'task_{}_config.json',
#     'checkpoint_freq': 0,
#     'trunc': 10,
#     'epsilon_start': 1.0,
#     'trace_decay': 0.9,
#     'blur_prob': 0.3,
#     'random_reward_start': False,
#     'distance_unc_encoding': False,
#     'distance_noise': False,
#     'size': 9,
#     'weight_init': 'fan_avg',
#     'exploration': 'eps',
#     'discounting': 0.9,
#     'value_step_size': 0.0001,
#     'p_prefilled': 0.0,
#     'n_hidden': 20,
#     'anneal_steps': 0,
#     'er_hidden_update': None,
#     'action_cond': None,
#     'atoms': 51,
#     'count_decay': 1.0,
#     'save_model': False,
#     'v_max': 100,
#     'buffer_size': 20000},
#    {'random_reward_start': False,
#     'max_episode_steps': 200,
#     'value_step_size': 0.0001,
#     'v_max': 100,
#     'test_episodes': 5,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'unnormalized_counts': False,
#     'epsilon': 1.0,
#     'buffer_size': 20000,
#     'half_efficiency_distance': 20.0,
#     'step_size': 1e-05,
#     'count_decay': 1.0,
#     'platform': 'cpu',
#     'view_test_ep': False,
#     'weight_init': 'fan_avg',
#     'p_prefilled': 0.0,
#     'seed': 2046,
#     'action_cond': None,
#     'discounting': 0.9,
#     'n_hidden': 20,
#     'exploration': 'eps',
#     'offline_eval_freq': 0,
#     'trace_decay': 0.9,
#     'epsilon_start': 1.0,
#     'size': 9,
#     'distance_unc_encoding': False,
#     'distributional': False,
#     'arch': 'nn',
#     'same_k_rnn_params': False,
#     'total_steps': 500000,
#     'fixed_gvf_path': None,
#     'slip_turn': False,
#     'v_min': -10,
#     'slip_prob': 0.0,
#     'init_hidden_var': 0.0,
#     'batch_size': 64,
#     'resample_interval': 1,
#     'algo': 'sarsa',
#     'trunc': 10,
#     'checkpoint_freq': 0,
#     'anneal_steps': 0,
#     'uncertainty_decay': 1.0,
#     'distance_noise': False,
#     'random_start': True,
#     'replay': False,
#     'po_degree': 0.0,
#     'k_rnn_hs': 1,
#     'save_all_checkpoints': False,
#     'task_fname': 'task_{}_config.json',
#     'optim': 'adam',
#     'n_particles': -1,
#     'er_hidden_update': None,
#     'env': '2t',
#     'save_model': False,
#     'atoms': 51,
#     'update_weight_interval': 1,
#     'blur_prob': 0.3,
#     'rock_obs_init': 0.0,
#     'test_eps': 0.0},
#    {'total_steps': 500000,
#     'distance_unc_encoding': False,
#     'n_particles': -1,
#     'arch': 'nn',
#     'save_model': False,
#     'update_weight_interval': 1,
#     'weight_init': 'fan_avg',
#     'same_k_rnn_params': False,
#     'slip_turn': False,
#     'optim': 'adam',
#     'platform': 'cpu',
#     'action_cond': None,
#     'view_test_ep': False,
#     'slip_prob': 0.0,
#     'half_efficiency_distance': 20.0,
#     'po_degree': 0.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'unnormalized_counts': False,
#     'batch_size': 64,
#     'k_rnn_hs': 1,
#     'save_all_checkpoints': False,
#     'epsilon_start': 1.0,
#     'step_size': 1e-05,
#     'random_start': True,
#     'fixed_gvf_path': None,
#     'seed': 2043,
#     'distributional': False,
#     'trace_decay': 0.9,
#     'trunc': 10,
#     'er_hidden_update': None,
#     'atoms': 51,
#     'blur_prob': 0.3,
#     'task_fname': 'task_{}_config.json',
#     'size': 9,
#     'random_reward_start': False,
#     'discounting': 0.9,
#     'n_hidden': 20,
#     'test_eps': 0.0,
#     'v_min': -10,
#     'checkpoint_freq': 0,
#     'algo': 'sarsa',
#     'v_max': 100,
#     'count_decay': 1.0,
#     'buffer_size': 20000,
#     'distance_noise': False,
#     'init_hidden_var': 0.0,
#     'epsilon': 1.0,
#     'env': '2t',
#     'max_episode_steps': 200,
#     'value_step_size': 0.0001,
#     'resample_interval': 1,
#     'exploration': 'eps',
#     'offline_eval_freq': 0,
#     'rock_obs_init': 0.0,
#     'replay': False,
#     'anneal_steps': 0,
#     'test_episodes': 5,
#     'uncertainty_decay': 1.0,
#     'p_prefilled': 0.0},
#    {'test_episodes': 5,
#     'er_hidden_update': None,
#     'step_size': 1e-05,
#     'init_hidden_var': 0.0,
#     'slip_turn': False,
#     'rock_obs_init': 0.0,
#     'max_episode_steps': 200,
#     'weight_init': 'fan_avg',
#     'value_step_size': 0.0001,
#     'optim': 'adam',
#     'half_efficiency_distance': 20.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'v_max': 100,
#     'algo': 'sarsa',
#     'update_weight_interval': 1,
#     'trace_decay': 0.9,
#     'task_fname': 'task_{}_config.json',
#     'epsilon': 1.0,
#     'action_cond': None,
#     'view_test_ep': False,
#     'arch': 'nn',
#     'buffer_size': 20000,
#     'n_particles': -1,
#     'atoms': 51,
#     'anneal_steps': 0,
#     'count_decay': 1.0,
#     'total_steps': 500000,
#     'uncertainty_decay': 1.0,
#     'test_eps': 0.0,
#     'random_start': True,
#     'random_reward_start': False,
#     'unnormalized_counts': False,
#     'v_min': -10,
#     'epsilon_start': 1.0,
#     'size': 9,
#     'resample_interval': 1,
#     'distributional': False,
#     'replay': False,
#     'discounting': 0.9,
#     'env': '2t',
#     'p_prefilled': 0.0,
#     'platform': 'cpu',
#     'batch_size': 64,
#     'distance_unc_encoding': False,
#     'po_degree': 0.0,
#     'fixed_gvf_path': None,
#     'slip_prob': 0.0,
#     'seed': 2023,
#     'offline_eval_freq': 0,
#     'same_k_rnn_params': False,
#     'save_model': False,
#     'n_hidden': 20,
#     'k_rnn_hs': 1,
#     'distance_noise': False,
#     'blur_prob': 0.3,
#     'trunc': 10,
#     'checkpoint_freq': 0,
#     'exploration': 'eps',
#     'save_all_checkpoints': False},
#    {'v_max': 100,
#     'view_test_ep': False,
#     'same_k_rnn_params': False,
#     'replay': False,
#     'max_episode_steps': 200,
#     'offline_eval_freq': 0,
#     'save_model': False,
#     'algo': 'sarsa',
#     'optim': 'adam',
#     'init_hidden_var': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'anneal_steps': 0,
#     'unnormalized_counts': False,
#     'slip_prob': 0.0,
#     'discounting': 0.9,
#     'er_hidden_update': None,
#     'rock_obs_init': 0.0,
#     'update_weight_interval': 1,
#     'fixed_gvf_path': None,
#     'uncertainty_decay': 1.0,
#     'checkpoint_freq': 0,
#     'action_cond': None,
#     'weight_init': 'fan_avg',
#     'n_particles': -1,
#     'value_step_size': 0.0001,
#     'test_episodes': 5,
#     'n_hidden': 20,
#     'seed': 2039,
#     'count_decay': 1.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'size': 9,
#     'epsilon_start': 1.0,
#     'slip_turn': False,
#     'epsilon': 1.0,
#     'half_efficiency_distance': 20.0,
#     'po_degree': 0.0,
#     'total_steps': 500000,
#     'v_min': -10,
#     'exploration': 'eps',
#     'save_all_checkpoints': False,
#     'env': '2t',
#     'distance_noise': False,
#     'blur_prob': 0.3,
#     'p_prefilled': 0.0,
#     'distance_unc_encoding': False,
#     'platform': 'cpu',
#     'trace_decay': 0.9,
#     'test_eps': 0.0,
#     'random_start': True,
#     'batch_size': 64,
#     'trunc': 10,
#     'step_size': 1e-05,
#     'atoms': 51,
#     'k_rnn_hs': 1,
#     'buffer_size': 20000,
#     'resample_interval': 1,
#     'arch': 'nn',
#     'random_reward_start': False,
#     'distributional': False}],
#   [PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/93d18a6d7efdd16542210270c479d0fd_Mon Jul 11 13:54:57 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/bd61cb75b853d2421ce4fdf5da5babab_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/df7058e6d9aa3b9a6c0cd568e266d503_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/fe71ed8bcc8e584ae4cece5411f8a3ea_Tue Jul 12 11:00:09 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/f2730b831949e66f7697ac8b45ee2cb7_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/70441ff8ae0dee9e065dfb817296d99c_Mon Jul 11 13:54:57 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/3db64d624db23334242a54fe5380f168_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/bf8fc52fcca6a334fe198a4aca52df2b_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/7e1edcfc487b08ada166068321041bea_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/83ba333cd09d292ca0f19bf06302ff89_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/a6c9bcdedea30fe74896ce7c0b2f0718_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/5a8d787859e225155875cd0d70aa1814_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/23f475049d2710684604a3528f6bd7d7_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/bcd534d4098b4918b6a4ca0330cb12fb_Mon Jul 11 13:54:57 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/3959e79d900c2baffe74d0ff155fae0d_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/9f950c0841ce08a9298198f2394c8a7b_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/3addddaab07fed83b3954decb974102a_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/62397f6b0c7fa8371d189277ad240c69_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/7ad0e098e6fb25b76aa7a7d7226e32ee_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/bde3e91e89afc3b6353c4f0426e56741_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/ddd2ca53b14fa99b3e72481ce9d085db_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/cc499a90c2ebe85691878b202557a62e_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/0f3ab5d8f4167178f201c7add9dd1535_Mon Jul 11 13:54:57 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/b57a5d0c0cfb5e3213419375396c7da1_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/c7ce879b9c41b184daa65dc3df862281_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/b82359f3e005911394f74aa3664596a5_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/786f1ecea13ae86202a6894d4215c938_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/d4e7c7fc6dadbfc845b2170e6dd9934c_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/e1cf53f2aa57d88841873b777454ea60_Mon Jul 11 12:51:06 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/fe71ed8bcc8e584ae4cece5411f8a3ea_Mon Jul 11 13:54:57 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/61c21e48ee5726adee1f0ae700d79992_Mon Jul 11 12:51:06 2022.npy')])]

# %%
# Checkpoint directories are sorted by seed.
checkpoint_dirs = [None for i in range(len(all_best['2t_nn_prediction'][-2]))]


for arg, path in zip(all_best['2t_nn_prediction'][-2], all_best['2t_nn_prediction'][-1]):
    checkpoints_dir = path.parent / 'checkpoints'
    arg_checkpoint_name = path.name.split('_')[0]
    arg_checkpoint_dir = checkpoints_dir / arg_checkpoint_name
    latest_checkpoint_name = sorted(list(arg_checkpoint_dir.iterdir()))[-1].name
    slurm_results_dir = Path('/home/taodav/scratch/uncertainty/results/2t_nn_prediction')
    slurm_checkpoint_fname = slurm_results_dir / 'checkpoints' / arg_checkpoint_name / latest_checkpoint_name
    checkpoint_dirs[arg['seed'] - 2020] = str(slurm_checkpoint_fname)

# %%
checkpoint_dirs[:30]
# Out:
# ['/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/f1ae73a28536159489b708d248a8a02e/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/9ef9314dc18a228abc35095921646bfc/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/2147d68114ecd9bc91c236ddde5d8c2b/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/fd587082f2a90e8036bba1c0c11e7c46/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/cef489976dedec7ed44934333c05925e/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/aaafa5a2192e86755110ee9a92606e52/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/fe06cb483a7d0b65c2fb550821e82258/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/fb360bbcf03f8427fd4745be3be8e1c8/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/f477c940a56887a7e92178a9d6b76246/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/1d0ac42a0cd9b74daf98e75e44c44325/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/1e9de6e4a24b6bcc598af2d6d680a7c9/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/112459442e848f7ebf17a7f5b7863f51/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/976291b2fdf7f5843c1d6d8183dd2aa2/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/79dc73d53f07a2a033e1fe60d4d4c4d9/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/366daf56389b33190b42bd810ff96e73/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/343d5060be90873502b718f60729dfc5/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/3f99a11ac463c274de41c43c3d75971a/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/a39ea7523c22c9ec927ed44826859b7a/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/89573743929c1dc04943ab7aabf607d7/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/7b850f74bd481a91c16b5f647f7f19d6/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/f81c81ad055e74ff1b72c0f51d664dec/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/655c2e0bb5745fdca74dac5f9c1c6241/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/28593c85c1417c821ec69855800f46da/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/31914b198afcb6653f6814f28b1ed341/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/f40b16829a5e6f632cdab8aed8b62cd9/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/0cb5ad39cf367fd27c10ddf75506b40b/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/247c5a815eefe2ff5beeee4133248fb0/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/f589733c851171ada4deae2506d0ced3/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/231c293512a4a50c4a1f17f5e50c2545/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/53a49c6c4808ff0e1484efe301d00b4f/500000.pkl']
