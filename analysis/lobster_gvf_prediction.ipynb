# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from tqdm.notebook import tqdm
from collections import namedtuple

from definitions import ROOT_DIR
from unc.utils import load_info

plt.rcParams.update({'font.size': 18})
# Out:
# /Users/ruoyutao/Documents/uncertainty/venv/lib/python3.8/site-packages/jax/_src/lib/__init__.py:33: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "

# %%
all_paths = {
    '2t_nn_prediction': Path(ROOT_DIR, 'results', '2t_nn_prediction')
}

split_by = ['step_size', 'epsilon']
Args = namedtuple('args', split_by)

# %%
def process_dir(dir_path, split_by):
    all_results = {}
        
    for f in tqdm(list(dir_path.iterdir())):
        if not f.is_file() or f.suffix != '.npy' or 'layer' in f.name:
            continue
        info = load_info(f)
        args = info['args'].item()
        
        hparams = Args(*tuple(args[s] for s in split_by))

        if hparams not in all_results:
            all_results[hparams] = []

#         all_results[hparams].append((info['episode_reward'], args))
        all_results[hparams].append((args, info['avg_episode_loss'], f))


    
    return all_results

# %%
raw_data = {}

for key, v in all_paths.items():
    processed = process_dir(v, split_by)
    
    raw_data[key] = {}
    for hparams, ret in processed.items():
        loss_lst, arg_lst, f_lst = [], [], []
        for r in ret:
            loss_lst.append(r[1])
            arg_lst.append(r[0])
            f_lst.append(r[2])
        raw_data[key][hparams] = {'loss': np.stack(loss_lst), 'args': arg_lst, 'paths': f_lst}
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]

# %%
# Here we get our best hparams
all_best = {}
best_over = 500

for key, res in raw_data.items():
    stats_list = []
    for args, rew_dict in res.items():
        # we take mean over both time and seeds
        stats_list.append((args, rew_dict['loss'][:, -best_over].mean(), rew_dict['loss'], rew_dict['args'], rew_dict['paths']))
    all_best[key] = sorted(stats_list, key=lambda x: x[1])[0]
# all_best['2t_nn_prediction'][-2]
[s for s in stats_list if s[0].step_size == 1e-5]
# Out:
# [(args(step_size=1e-05, epsilon=1.0),
#   0.10902104,
#   array([[0.08887608, 0.10727347, 0.09531257, ..., 0.10582814, 0.13916044,
#           0.11166141],
#          [0.1084057 , 0.12891631, 0.13388388, ..., 0.06999672, 0.0841626 ,
#           0.10832828],
#          [0.10730546, 0.09628888, 0.0976272 , ..., 0.04916447, 0.07499634,
#           0.09332876],
#          ...,
#          [0.14245696, 0.17409822, 0.14637515, ..., 0.09915948, 0.03249844,
#           0.05999561],
#          [0.13801372, 0.12022826, 0.09747491, ..., 0.08916309, 0.0849959 ,
#           0.05416443],
#          [0.10611156, 0.130829  , 0.13111934, ..., 0.1433242 , 0.07999524,
#           0.06916246]], dtype=float32),
#   [{'checkpoint_freq': 0,
#     'v_max': 100,
#     'exploration': 'eps',
#     'value_step_size': 0.0001,
#     'algo': 'sarsa',
#     'save_model': False,
#     'k_rnn_hs': 1,
#     'max_episode_steps': 200,
#     'task_fname': 'task_{}_config.json',
#     'offline_eval_freq': 0,
#     'batch_size': 64,
#     'init_hidden_var': 0.0,
#     'resample_interval': 1,
#     'optim': 'adam',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'n_hidden': 40,
#     'epsilon_start': 1.0,
#     'update_weight_interval': 1,
#     'po_degree': 0.0,
#     'discounting': 0.9,
#     'total_steps': 500000,
#     'random_reward_start': False,
#     'layers': 1,
#     'n_particles': -1,
#     'distance_noise': False,
#     'distance_unc_encoding': False,
#     'uncertainty_decay': 1.0,
#     'view_test_ep': False,
#     'atoms': 51,
#     'trunc': 10,
#     'env': '2t',
#     'half_efficiency_distance': 20.0,
#     'seed': 2027,
#     'replay': False,
#     'slip_turn': False,
#     'platform': 'cpu',
#     'count_decay': 1.0,
#     'rock_obs_init': 0.0,
#     'size': 9,
#     'blur_prob': 0.3,
#     'p_prefilled': 0.0,
#     'test_eps': 0.0,
#     'v_min': -10,
#     'anneal_steps': 0,
#     'save_all_checkpoints': False,
#     'slip_prob': 0.0,
#     'arch': 'nn',
#     'random_start': True,
#     'weight_init': 'fan_avg',
#     'er_hidden_update': None,
#     'epsilon': 1.0,
#     'distributional': False,
#     'unnormalized_counts': False,
#     'action_cond': None,
#     'step_size': 1e-05,
#     'trace_decay': 0.9,
#     'same_k_rnn_params': False,
#     'buffer_size': 20000,
#     'test_episodes': 5,
#     'fixed_gvf_path': None},
#    {'p_prefilled': 0.0,
#     'n_particles': -1,
#     'save_model': False,
#     'test_eps': 0.0,
#     'save_all_checkpoints': False,
#     'same_k_rnn_params': False,
#     'anneal_steps': 0,
#     'algo': 'sarsa',
#     'size': 9,
#     'layers': 1,
#     'discounting': 0.9,
#     'half_efficiency_distance': 20.0,
#     'er_hidden_update': None,
#     'k_rnn_hs': 1,
#     'epsilon': 1.0,
#     'v_max': 100,
#     'env': '2t',
#     'update_weight_interval': 1,
#     'batch_size': 64,
#     'random_start': True,
#     'fixed_gvf_path': None,
#     'slip_turn': False,
#     'platform': 'cpu',
#     'blur_prob': 0.3,
#     'value_step_size': 0.0001,
#     'random_reward_start': False,
#     'replay': False,
#     'unnormalized_counts': False,
#     'uncertainty_decay': 1.0,
#     'view_test_ep': False,
#     'buffer_size': 20000,
#     'rock_obs_init': 0.0,
#     'init_hidden_var': 0.0,
#     'max_episode_steps': 200,
#     'distributional': False,
#     'offline_eval_freq': 0,
#     'resample_interval': 1,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'checkpoint_freq': 0,
#     'count_decay': 1.0,
#     'step_size': 1e-05,
#     'arch': 'nn',
#     'po_degree': 0.0,
#     'seed': 2035,
#     'exploration': 'eps',
#     'slip_prob': 0.0,
#     'optim': 'adam',
#     'action_cond': None,
#     'distance_noise': False,
#     'v_min': -10,
#     'trace_decay': 0.9,
#     'trunc': 10,
#     'weight_init': 'fan_avg',
#     'atoms': 51,
#     'task_fname': 'task_{}_config.json',
#     'distance_unc_encoding': False,
#     'test_episodes': 5,
#     'epsilon_start': 1.0,
#     'total_steps': 500000,
#     'n_hidden': 40},
#    {'same_k_rnn_params': False,
#     'update_weight_interval': 1,
#     'test_episodes': 5,
#     'v_min': -10,
#     'k_rnn_hs': 1,
#     'replay': False,
#     'anneal_steps': 0,
#     'distributional': False,
#     'rock_obs_init': 0.0,
#     'optim': 'adam',
#     'weight_init': 'fan_avg',
#     'checkpoint_freq': 0,
#     'count_decay': 1.0,
#     'er_hidden_update': None,
#     'half_efficiency_distance': 20.0,
#     'value_step_size': 0.0001,
#     'init_hidden_var': 0.0,
#     'epsilon_start': 1.0,
#     'arch': 'nn',
#     'max_episode_steps': 200,
#     'offline_eval_freq': 0,
#     'action_cond': None,
#     'resample_interval': 1,
#     'buffer_size': 20000,
#     'atoms': 51,
#     'n_particles': -1,
#     'distance_noise': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'n_hidden': 40,
#     'task_fname': 'task_{}_config.json',
#     'unnormalized_counts': False,
#     'test_eps': 0.0,
#     'distance_unc_encoding': False,
#     'env': '2t',
#     'exploration': 'eps',
#     'random_start': True,
#     'epsilon': 1.0,
#     'total_steps': 500000,
#     'po_degree': 0.0,
#     'slip_turn': False,
#     'p_prefilled': 0.0,
#     'v_max': 100,
#     'save_all_checkpoints': False,
#     'size': 9,
#     'trace_decay': 0.9,
#     'fixed_gvf_path': None,
#     'batch_size': 64,
#     'layers': 1,
#     'view_test_ep': False,
#     'platform': 'cpu',
#     'random_reward_start': False,
#     'save_model': False,
#     'uncertainty_decay': 1.0,
#     'step_size': 1e-05,
#     'discounting': 0.9,
#     'blur_prob': 0.3,
#     'seed': 2037,
#     'algo': 'sarsa',
#     'trunc': 10,
#     'slip_prob': 0.0},
#    {'size': 9,
#     'epsilon': 1.0,
#     'resample_interval': 1,
#     'rock_obs_init': 0.0,
#     'test_episodes': 5,
#     'k_rnn_hs': 1,
#     'distributional': False,
#     'platform': 'cpu',
#     'save_model': False,
#     'epsilon_start': 1.0,
#     'random_reward_start': False,
#     'action_cond': None,
#     'distance_unc_encoding': False,
#     'step_size': 1e-05,
#     'trace_decay': 0.9,
#     'batch_size': 64,
#     'blur_prob': 0.3,
#     'discounting': 0.9,
#     'atoms': 51,
#     'fixed_gvf_path': None,
#     'po_degree': 0.0,
#     'distance_noise': False,
#     'checkpoint_freq': 0,
#     'trunc': 10,
#     'slip_turn': False,
#     'arch': 'nn',
#     'value_step_size': 0.0001,
#     'update_weight_interval': 1,
#     'count_decay': 1.0,
#     'random_start': True,
#     'algo': 'sarsa',
#     'optim': 'adam',
#     'slip_prob': 0.0,
#     'env': '2t',
#     'init_hidden_var': 0.0,
#     'view_test_ep': False,
#     'n_particles': -1,
#     'weight_init': 'fan_avg',
#     'v_min': -10,
#     'anneal_steps': 0,
#     'max_episode_steps': 200,
#     'n_hidden': 40,
#     'task_fname': 'task_{}_config.json',
#     'save_all_checkpoints': False,
#     'seed': 2045,
#     'v_max': 100,
#     'exploration': 'eps',
#     'buffer_size': 20000,
#     'offline_eval_freq': 0,
#     'uncertainty_decay': 1.0,
#     'half_efficiency_distance': 20.0,
#     'replay': False,
#     'layers': 1,
#     'er_hidden_update': None,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'p_prefilled': 0.0,
#     'test_eps': 0.0,
#     'total_steps': 500000,
#     'same_k_rnn_params': False,
#     'unnormalized_counts': False},
#    {'layers': 1,
#     'value_step_size': 0.0001,
#     'v_min': -10,
#     'uncertainty_decay': 1.0,
#     'max_episode_steps': 200,
#     'optim': 'adam',
#     'buffer_size': 20000,
#     'platform': 'cpu',
#     'po_degree': 0.0,
#     'slip_turn': False,
#     'trace_decay': 0.9,
#     'init_hidden_var': 0.0,
#     'v_max': 100,
#     'half_efficiency_distance': 20.0,
#     'n_particles': -1,
#     'action_cond': None,
#     'random_reward_start': False,
#     'p_prefilled': 0.0,
#     'checkpoint_freq': 0,
#     'anneal_steps': 0,
#     'offline_eval_freq': 0,
#     'total_steps': 500000,
#     'epsilon_start': 1.0,
#     'test_eps': 0.0,
#     'seed': 2041,
#     'save_all_checkpoints': False,
#     'slip_prob': 0.0,
#     'n_hidden': 40,
#     'step_size': 1e-05,
#     'fixed_gvf_path': None,
#     'count_decay': 1.0,
#     'algo': 'sarsa',
#     'atoms': 51,
#     'discounting': 0.9,
#     'exploration': 'eps',
#     'distance_unc_encoding': False,
#     'env': '2t',
#     'weight_init': 'fan_avg',
#     'epsilon': 1.0,
#     'arch': 'nn',
#     'distance_noise': False,
#     'rock_obs_init': 0.0,
#     'test_episodes': 5,
#     'k_rnn_hs': 1,
#     'save_model': False,
#     'batch_size': 64,
#     'blur_prob': 0.3,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'distributional': False,
#     'resample_interval': 1,
#     'same_k_rnn_params': False,
#     'view_test_ep': False,
#     'task_fname': 'task_{}_config.json',
#     'update_weight_interval': 1,
#     'unnormalized_counts': False,
#     'replay': False,
#     'trunc': 10,
#     'size': 9,
#     'random_start': True,
#     'er_hidden_update': None},
#    {'size': 9,
#     'random_reward_start': False,
#     'rock_obs_init': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'unnormalized_counts': False,
#     'n_particles': -1,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'seed': 2036,
#     'total_steps': 500000,
#     'checkpoint_freq': 0,
#     'replay': False,
#     'v_min': -10,
#     'exploration': 'eps',
#     'max_episode_steps': 200,
#     'test_episodes': 5,
#     'er_hidden_update': None,
#     'k_rnn_hs': 1,
#     'update_weight_interval': 1,
#     'slip_prob': 0.0,
#     'offline_eval_freq': 0,
#     'trace_decay': 0.9,
#     'batch_size': 64,
#     'distance_noise': False,
#     'uncertainty_decay': 1.0,
#     'buffer_size': 20000,
#     'po_degree': 0.0,
#     'action_cond': None,
#     'init_hidden_var': 0.0,
#     'view_test_ep': False,
#     'epsilon': 1.0,
#     'distance_unc_encoding': False,
#     'platform': 'cpu',
#     'fixed_gvf_path': None,
#     'discounting': 0.9,
#     'arch': 'nn',
#     'resample_interval': 1,
#     'p_prefilled': 0.0,
#     'trunc': 10,
#     'test_eps': 0.0,
#     'n_hidden': 40,
#     'save_all_checkpoints': False,
#     'half_efficiency_distance': 20.0,
#     'algo': 'sarsa',
#     'random_start': True,
#     'save_model': False,
#     'count_decay': 1.0,
#     'atoms': 51,
#     'layers': 1,
#     'step_size': 1e-05,
#     'slip_turn': False,
#     'v_max': 100,
#     'distributional': False,
#     'same_k_rnn_params': False,
#     'weight_init': 'fan_avg',
#     'anneal_steps': 0,
#     'value_step_size': 0.0001,
#     'blur_prob': 0.3,
#     'env': '2t',
#     'epsilon_start': 1.0,
#     'optim': 'adam'},
#    {'trunc': 10,
#     'algo': 'sarsa',
#     'slip_prob': 0.0,
#     'layers': 1,
#     'replay': False,
#     'uncertainty_decay': 1.0,
#     'same_k_rnn_params': False,
#     'unnormalized_counts': False,
#     'platform': 'cpu',
#     'buffer_size': 20000,
#     'count_decay': 1.0,
#     'distributional': False,
#     'task_fname': 'task_{}_config.json',
#     'er_hidden_update': None,
#     'anneal_steps': 0,
#     'value_step_size': 0.0001,
#     'test_episodes': 5,
#     'n_particles': -1,
#     'total_steps': 500000,
#     'save_all_checkpoints': False,
#     'seed': 2031,
#     'arch': 'nn',
#     'offline_eval_freq': 0,
#     'action_cond': None,
#     'discounting': 0.9,
#     'optim': 'adam',
#     'resample_interval': 1,
#     'half_efficiency_distance': 20.0,
#     'batch_size': 64,
#     'random_reward_start': False,
#     'distance_unc_encoding': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'atoms': 51,
#     'init_hidden_var': 0.0,
#     'weight_init': 'fan_avg',
#     'test_eps': 0.0,
#     'save_model': False,
#     'size': 9,
#     'step_size': 1e-05,
#     'distance_noise': False,
#     'slip_turn': False,
#     'epsilon': 1.0,
#     'n_hidden': 40,
#     'p_prefilled': 0.0,
#     'view_test_ep': False,
#     'epsilon_start': 1.0,
#     'env': '2t',
#     'trace_decay': 0.9,
#     'max_episode_steps': 200,
#     'checkpoint_freq': 0,
#     'exploration': 'eps',
#     'v_max': 100,
#     'rock_obs_init': 0.0,
#     'v_min': -10,
#     'update_weight_interval': 1,
#     'fixed_gvf_path': None,
#     'k_rnn_hs': 1,
#     'po_degree': 0.0,
#     'random_start': True,
#     'blur_prob': 0.3},
#    {'exploration': 'eps',
#     'fixed_gvf_path': None,
#     'rock_obs_init': 0.0,
#     'n_particles': -1,
#     'layers': 1,
#     'save_all_checkpoints': False,
#     'v_min': -10,
#     'total_steps': 500000,
#     'value_step_size': 0.0001,
#     'discounting': 0.9,
#     'distance_unc_encoding': False,
#     'count_decay': 1.0,
#     'distance_noise': False,
#     'v_max': 100,
#     'trunc': 10,
#     'task_fname': 'task_{}_config.json',
#     'blur_prob': 0.3,
#     'test_episodes': 5,
#     'n_hidden': 40,
#     'weight_init': 'fan_avg',
#     'buffer_size': 20000,
#     'distributional': False,
#     'checkpoint_freq': 0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'unnormalized_counts': False,
#     'p_prefilled': 0.0,
#     'action_cond': None,
#     'k_rnn_hs': 1,
#     'po_degree': 0.0,
#     'anneal_steps': 0,
#     'offline_eval_freq': 0,
#     'random_start': True,
#     'optim': 'adam',
#     'trace_decay': 0.9,
#     'save_model': False,
#     'step_size': 1e-05,
#     'test_eps': 0.0,
#     'epsilon': 1.0,
#     'er_hidden_update': None,
#     'random_reward_start': False,
#     'replay': False,
#     'arch': 'nn',
#     'platform': 'cpu',
#     'init_hidden_var': 0.0,
#     'algo': 'sarsa',
#     'max_episode_steps': 200,
#     'slip_turn': False,
#     'size': 9,
#     'resample_interval': 1,
#     'seed': 2030,
#     'uncertainty_decay': 1.0,
#     'same_k_rnn_params': False,
#     'epsilon_start': 1.0,
#     'update_weight_interval': 1,
#     'slip_prob': 0.0,
#     'view_test_ep': False,
#     'half_efficiency_distance': 20.0,
#     'batch_size': 64,
#     'atoms': 51,
#     'env': '2t'},
#    {'k_rnn_hs': 1,
#     'save_all_checkpoints': False,
#     'algo': 'sarsa',
#     'batch_size': 64,
#     'count_decay': 1.0,
#     'buffer_size': 20000,
#     'rock_obs_init': 0.0,
#     'seed': 2046,
#     'v_max': 100,
#     'trace_decay': 0.9,
#     'test_episodes': 5,
#     'atoms': 51,
#     'fixed_gvf_path': None,
#     'trunc': 10,
#     'random_reward_start': False,
#     'checkpoint_freq': 0,
#     'er_hidden_update': None,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'distributional': False,
#     'platform': 'cpu',
#     'epsilon': 1.0,
#     'p_prefilled': 0.0,
#     'random_start': True,
#     'distance_unc_encoding': False,
#     'optim': 'adam',
#     'save_model': False,
#     'slip_turn': False,
#     'same_k_rnn_params': False,
#     'env': '2t',
#     'blur_prob': 0.3,
#     'uncertainty_decay': 1.0,
#     'unnormalized_counts': False,
#     'arch': 'nn',
#     'discounting': 0.9,
#     'half_efficiency_distance': 20.0,
#     'distance_noise': False,
#     'step_size': 1e-05,
#     'value_step_size': 0.0001,
#     'view_test_ep': False,
#     'v_min': -10,
#     'epsilon_start': 1.0,
#     'layers': 1,
#     'n_hidden': 40,
#     'weight_init': 'fan_avg',
#     'anneal_steps': 0,
#     'update_weight_interval': 1,
#     'task_fname': 'task_{}_config.json',
#     'n_particles': -1,
#     'total_steps': 500000,
#     'max_episode_steps': 200,
#     'action_cond': None,
#     'resample_interval': 1,
#     'test_eps': 0.0,
#     'slip_prob': 0.0,
#     'size': 9,
#     'exploration': 'eps',
#     'po_degree': 0.0,
#     'offline_eval_freq': 0,
#     'init_hidden_var': 0.0,
#     'replay': False},
#    {'p_prefilled': 0.0,
#     'buffer_size': 20000,
#     'same_k_rnn_params': False,
#     'slip_prob': 0.0,
#     'batch_size': 64,
#     'v_max': 100,
#     'offline_eval_freq': 0,
#     'arch': 'nn',
#     'random_start': True,
#     'count_decay': 1.0,
#     'v_min': -10,
#     'fixed_gvf_path': None,
#     'step_size': 1e-05,
#     'task_fname': 'task_{}_config.json',
#     'replay': False,
#     'test_eps': 0.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'n_hidden': 40,
#     'init_hidden_var': 0.0,
#     'half_efficiency_distance': 20.0,
#     'action_cond': None,
#     'trunc': 10,
#     'atoms': 51,
#     'anneal_steps': 0,
#     'epsilon_start': 1.0,
#     'exploration': 'eps',
#     'save_model': False,
#     'unnormalized_counts': False,
#     'size': 9,
#     'max_episode_steps': 200,
#     'value_step_size': 0.0001,
#     'blur_prob': 0.3,
#     'view_test_ep': False,
#     'distributional': False,
#     'random_reward_start': False,
#     'k_rnn_hs': 1,
#     'er_hidden_update': None,
#     'save_all_checkpoints': False,
#     'resample_interval': 1,
#     'discounting': 0.9,
#     'weight_init': 'fan_avg',
#     'uncertainty_decay': 1.0,
#     'seed': 2023,
#     'env': '2t',
#     'epsilon': 1.0,
#     'update_weight_interval': 1,
#     'slip_turn': False,
#     'po_degree': 0.0,
#     'trace_decay': 0.9,
#     'optim': 'adam',
#     'distance_noise': False,
#     'layers': 1,
#     'platform': 'cpu',
#     'rock_obs_init': 0.0,
#     'total_steps': 500000,
#     'distance_unc_encoding': False,
#     'test_episodes': 5,
#     'algo': 'sarsa',
#     'n_particles': -1,
#     'checkpoint_freq': 0},
#    {'distributional': False,
#     'value_step_size': 0.0001,
#     'p_prefilled': 0.0,
#     'test_episodes': 5,
#     'v_max': 100,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'uncertainty_decay': 1.0,
#     'atoms': 51,
#     'v_min': -10,
#     'task_fname': 'task_{}_config.json',
#     'distance_noise': False,
#     'resample_interval': 1,
#     'max_episode_steps': 200,
#     'count_decay': 1.0,
#     'env': '2t',
#     'layers': 1,
#     'fixed_gvf_path': None,
#     'buffer_size': 20000,
#     'size': 9,
#     'seed': 2043,
#     'init_hidden_var': 0.0,
#     'epsilon': 1.0,
#     'random_start': True,
#     'trunc': 10,
#     'discounting': 0.9,
#     'arch': 'nn',
#     'algo': 'sarsa',
#     'update_weight_interval': 1,
#     'n_particles': -1,
#     'weight_init': 'fan_avg',
#     'blur_prob': 0.3,
#     'save_all_checkpoints': False,
#     'er_hidden_update': None,
#     'total_steps': 500000,
#     'k_rnn_hs': 1,
#     'batch_size': 64,
#     'offline_eval_freq': 0,
#     'distance_unc_encoding': False,
#     'test_eps': 0.0,
#     'half_efficiency_distance': 20.0,
#     'replay': False,
#     'slip_turn': False,
#     'view_test_ep': False,
#     'platform': 'cpu',
#     'rock_obs_init': 0.0,
#     'same_k_rnn_params': False,
#     'trace_decay': 0.9,
#     'anneal_steps': 0,
#     'slip_prob': 0.0,
#     'step_size': 1e-05,
#     'unnormalized_counts': False,
#     'epsilon_start': 1.0,
#     'optim': 'adam',
#     'checkpoint_freq': 0,
#     'save_model': False,
#     'exploration': 'eps',
#     'random_reward_start': False,
#     'n_hidden': 40,
#     'po_degree': 0.0,
#     'action_cond': None},
#    {'value_step_size': 0.0001,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'exploration': 'eps',
#     'v_min': -10,
#     'unnormalized_counts': False,
#     'optim': 'adam',
#     'update_weight_interval': 1,
#     'random_start': True,
#     'trace_decay': 0.9,
#     'view_test_ep': False,
#     'batch_size': 64,
#     'action_cond': None,
#     'fixed_gvf_path': None,
#     'uncertainty_decay': 1.0,
#     'size': 9,
#     'init_hidden_var': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'test_episodes': 5,
#     'distance_unc_encoding': False,
#     'layers': 1,
#     'trunc': 10,
#     'po_degree': 0.0,
#     'same_k_rnn_params': False,
#     'resample_interval': 1,
#     'offline_eval_freq': 0,
#     'blur_prob': 0.3,
#     'test_eps': 0.0,
#     'seed': 2048,
#     'anneal_steps': 0,
#     'v_max': 100,
#     'step_size': 1e-05,
#     'slip_prob': 0.0,
#     'weight_init': 'fan_avg',
#     'rock_obs_init': 0.0,
#     'discounting': 0.9,
#     'atoms': 51,
#     'er_hidden_update': None,
#     'p_prefilled': 0.0,
#     'buffer_size': 20000,
#     'count_decay': 1.0,
#     'algo': 'sarsa',
#     'distance_noise': False,
#     'max_episode_steps': 200,
#     'distributional': False,
#     'platform': 'cpu',
#     'random_reward_start': False,
#     'n_particles': -1,
#     'epsilon': 1.0,
#     'arch': 'nn',
#     'n_hidden': 40,
#     'total_steps': 500000,
#     'env': '2t',
#     'replay': False,
#     'save_all_checkpoints': False,
#     'epsilon_start': 1.0,
#     'checkpoint_freq': 0,
#     'k_rnn_hs': 1,
#     'slip_turn': False,
#     'save_model': False,
#     'half_efficiency_distance': 20.0},
#    {'arch': 'nn',
#     'offline_eval_freq': 0,
#     'algo': 'sarsa',
#     'seed': 2032,
#     'count_decay': 1.0,
#     'random_start': True,
#     'fixed_gvf_path': None,
#     'init_hidden_var': 0.0,
#     'random_reward_start': False,
#     'epsilon_start': 1.0,
#     'weight_init': 'fan_avg',
#     'slip_turn': False,
#     'discounting': 0.9,
#     'epsilon': 1.0,
#     'batch_size': 64,
#     'platform': 'cpu',
#     'save_all_checkpoints': False,
#     'slip_prob': 0.0,
#     'test_eps': 0.0,
#     'distributional': False,
#     'distance_unc_encoding': False,
#     'atoms': 51,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'env': '2t',
#     'half_efficiency_distance': 20.0,
#     'save_model': False,
#     'p_prefilled': 0.0,
#     'test_episodes': 5,
#     'layers': 1,
#     'n_particles': -1,
#     'same_k_rnn_params': False,
#     'buffer_size': 20000,
#     'update_weight_interval': 1,
#     'v_min': -10,
#     'task_fname': 'task_{}_config.json',
#     'action_cond': None,
#     'max_episode_steps': 200,
#     'blur_prob': 0.3,
#     'uncertainty_decay': 1.0,
#     'exploration': 'eps',
#     'er_hidden_update': None,
#     'trunc': 10,
#     'anneal_steps': 0,
#     'k_rnn_hs': 1,
#     'total_steps': 500000,
#     'v_max': 100,
#     'distance_noise': False,
#     'value_step_size': 0.0001,
#     'unnormalized_counts': False,
#     'replay': False,
#     'po_degree': 0.0,
#     'trace_decay': 0.9,
#     'resample_interval': 1,
#     'size': 9,
#     'step_size': 1e-05,
#     'view_test_ep': False,
#     'n_hidden': 40,
#     'rock_obs_init': 0.0,
#     'checkpoint_freq': 0,
#     'optim': 'adam'},
#    {'save_model': False,
#     'random_start': True,
#     'random_reward_start': False,
#     'epsilon': 1.0,
#     'count_decay': 1.0,
#     'n_particles': -1,
#     'fixed_gvf_path': None,
#     'atoms': 51,
#     'weight_init': 'fan_avg',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'trace_decay': 0.9,
#     'arch': 'nn',
#     'layers': 1,
#     'update_weight_interval': 1,
#     'test_eps': 0.0,
#     'resample_interval': 1,
#     'action_cond': None,
#     'total_steps': 500000,
#     'checkpoint_freq': 0,
#     'er_hidden_update': None,
#     'algo': 'sarsa',
#     'v_max': 100,
#     'po_degree': 0.0,
#     'k_rnn_hs': 1,
#     'discounting': 0.9,
#     'anneal_steps': 0,
#     'distance_unc_encoding': False,
#     'same_k_rnn_params': False,
#     'batch_size': 64,
#     'offline_eval_freq': 0,
#     'save_all_checkpoints': False,
#     'value_step_size': 0.0001,
#     'seed': 2039,
#     'slip_prob': 0.0,
#     'epsilon_start': 1.0,
#     'uncertainty_decay': 1.0,
#     'test_episodes': 5,
#     'optim': 'adam',
#     'replay': False,
#     'rock_obs_init': 0.0,
#     'distance_noise': False,
#     'slip_turn': False,
#     'v_min': -10,
#     'blur_prob': 0.3,
#     'step_size': 1e-05,
#     'unnormalized_counts': False,
#     'half_efficiency_distance': 20.0,
#     'view_test_ep': False,
#     'max_episode_steps': 200,
#     'platform': 'cpu',
#     'n_hidden': 40,
#     'buffer_size': 20000,
#     'distributional': False,
#     'env': '2t',
#     'trunc': 10,
#     'init_hidden_var': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'size': 9,
#     'exploration': 'eps',
#     'p_prefilled': 0.0},
#    {'count_decay': 1.0,
#     'epsilon': 1.0,
#     'save_all_checkpoints': False,
#     'optim': 'adam',
#     'algo': 'sarsa',
#     'uncertainty_decay': 1.0,
#     'test_episodes': 5,
#     'unnormalized_counts': False,
#     'distributional': False,
#     'arch': 'nn',
#     'resample_interval': 1,
#     'offline_eval_freq': 0,
#     'update_weight_interval': 1,
#     'n_hidden': 40,
#     'view_test_ep': False,
#     'random_reward_start': False,
#     'fixed_gvf_path': None,
#     'action_cond': None,
#     'atoms': 51,
#     'buffer_size': 20000,
#     'save_model': False,
#     'checkpoint_freq': 0,
#     'init_hidden_var': 0.0,
#     'slip_prob': 0.0,
#     'blur_prob': 0.3,
#     'v_max': 100,
#     'step_size': 1e-05,
#     'epsilon_start': 1.0,
#     'v_min': -10,
#     'er_hidden_update': None,
#     'weight_init': 'fan_avg',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'slip_turn': False,
#     'value_step_size': 0.0001,
#     'distance_noise': False,
#     'trace_decay': 0.9,
#     'k_rnn_hs': 1,
#     'platform': 'cpu',
#     'half_efficiency_distance': 20.0,
#     'batch_size': 64,
#     'po_degree': 0.0,
#     'trunc': 10,
#     'seed': 2025,
#     'max_episode_steps': 200,
#     'rock_obs_init': 0.0,
#     'replay': False,
#     'n_particles': -1,
#     'total_steps': 500000,
#     'size': 9,
#     'test_eps': 0.0,
#     'env': '2t',
#     'discounting': 0.9,
#     'distance_unc_encoding': False,
#     'layers': 1,
#     'random_start': True,
#     'task_fname': 'task_{}_config.json',
#     'exploration': 'eps',
#     'anneal_steps': 0,
#     'same_k_rnn_params': False,
#     'p_prefilled': 0.0},
#    {'arch': 'nn',
#     'action_cond': None,
#     'batch_size': 64,
#     'v_min': -10,
#     'distance_noise': False,
#     'weight_init': 'fan_avg',
#     'save_all_checkpoints': False,
#     'buffer_size': 20000,
#     'step_size': 1e-05,
#     'v_max': 100,
#     'size': 9,
#     'random_reward_start': False,
#     'optim': 'adam',
#     'test_eps': 0.0,
#     'n_particles': -1,
#     'platform': 'cpu',
#     'unnormalized_counts': False,
#     'algo': 'sarsa',
#     'layers': 1,
#     'half_efficiency_distance': 20.0,
#     'k_rnn_hs': 1,
#     'rock_obs_init': 0.0,
#     'blur_prob': 0.3,
#     'er_hidden_update': None,
#     'n_hidden': 40,
#     'view_test_ep': False,
#     'count_decay': 1.0,
#     'init_hidden_var': 0.0,
#     'fixed_gvf_path': None,
#     'value_step_size': 0.0001,
#     'max_episode_steps': 200,
#     'trunc': 10,
#     'same_k_rnn_params': False,
#     'random_start': True,
#     'save_model': False,
#     'distributional': False,
#     'trace_decay': 0.9,
#     'discounting': 0.9,
#     'seed': 2049,
#     'slip_turn': False,
#     'po_degree': 0.0,
#     'slip_prob': 0.0,
#     'exploration': 'eps',
#     'checkpoint_freq': 0,
#     'atoms': 51,
#     'total_steps': 500000,
#     'test_episodes': 5,
#     'replay': False,
#     'anneal_steps': 0,
#     'resample_interval': 1,
#     'epsilon_start': 1.0,
#     'epsilon': 1.0,
#     'env': '2t',
#     'distance_unc_encoding': False,
#     'offline_eval_freq': 0,
#     'update_weight_interval': 1,
#     'task_fname': 'task_{}_config.json',
#     'p_prefilled': 0.0,
#     'uncertainty_decay': 1.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn')},
#    {'same_k_rnn_params': False,
#     'total_steps': 500000,
#     'test_episodes': 5,
#     'fixed_gvf_path': None,
#     'discounting': 0.9,
#     'n_hidden': 40,
#     'save_all_checkpoints': False,
#     'algo': 'sarsa',
#     'layers': 1,
#     'po_degree': 0.0,
#     'optim': 'adam',
#     'seed': 2033,
#     'slip_prob': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'rock_obs_init': 0.0,
#     'trace_decay': 0.9,
#     'epsilon_start': 1.0,
#     'anneal_steps': 0,
#     'atoms': 51,
#     'random_start': True,
#     'offline_eval_freq': 0,
#     'replay': False,
#     'exploration': 'eps',
#     'batch_size': 64,
#     'random_reward_start': False,
#     'v_max': 100,
#     'init_hidden_var': 0.0,
#     'step_size': 1e-05,
#     'unnormalized_counts': False,
#     'half_efficiency_distance': 20.0,
#     'count_decay': 1.0,
#     'trunc': 10,
#     'distributional': False,
#     'k_rnn_hs': 1,
#     'p_prefilled': 0.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'test_eps': 0.0,
#     'update_weight_interval': 1,
#     'buffer_size': 20000,
#     'max_episode_steps': 200,
#     'uncertainty_decay': 1.0,
#     'blur_prob': 0.3,
#     'er_hidden_update': None,
#     'action_cond': None,
#     'platform': 'cpu',
#     'slip_turn': False,
#     'distance_noise': False,
#     'save_model': False,
#     'n_particles': -1,
#     'v_min': -10,
#     'epsilon': 1.0,
#     'checkpoint_freq': 0,
#     'distance_unc_encoding': False,
#     'weight_init': 'fan_avg',
#     'resample_interval': 1,
#     'env': '2t',
#     'size': 9,
#     'value_step_size': 0.0001,
#     'view_test_ep': False,
#     'arch': 'nn'},
#    {'layers': 1,
#     'optim': 'adam',
#     'po_degree': 0.0,
#     'exploration': 'eps',
#     'fixed_gvf_path': None,
#     'algo': 'sarsa',
#     'size': 9,
#     'er_hidden_update': None,
#     'epsilon': 1.0,
#     'distance_noise': False,
#     'slip_turn': False,
#     'v_min': -10,
#     'same_k_rnn_params': False,
#     'init_hidden_var': 0.0,
#     'distributional': False,
#     'weight_init': 'fan_avg',
#     'discounting': 0.9,
#     'k_rnn_hs': 1,
#     'random_start': True,
#     'batch_size': 64,
#     'random_reward_start': False,
#     'view_test_ep': False,
#     'blur_prob': 0.3,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'task_fname': 'task_{}_config.json',
#     'step_size': 1e-05,
#     'distance_unc_encoding': False,
#     'arch': 'nn',
#     'count_decay': 1.0,
#     'atoms': 51,
#     'seed': 2021,
#     'v_max': 100,
#     'offline_eval_freq': 0,
#     'test_eps': 0.0,
#     'save_model': False,
#     'env': '2t',
#     'half_efficiency_distance': 20.0,
#     'p_prefilled': 0.0,
#     'slip_prob': 0.0,
#     'uncertainty_decay': 1.0,
#     'checkpoint_freq': 0,
#     'epsilon_start': 1.0,
#     'max_episode_steps': 200,
#     'value_step_size': 0.0001,
#     'buffer_size': 20000,
#     'unnormalized_counts': False,
#     'trunc': 10,
#     'n_hidden': 40,
#     'rock_obs_init': 0.0,
#     'total_steps': 500000,
#     'action_cond': None,
#     'test_episodes': 5,
#     'resample_interval': 1,
#     'update_weight_interval': 1,
#     'save_all_checkpoints': False,
#     'anneal_steps': 0,
#     'n_particles': -1,
#     'platform': 'cpu',
#     'replay': False,
#     'trace_decay': 0.9},
#    {'batch_size': 64,
#     'test_episodes': 5,
#     'total_steps': 500000,
#     'slip_turn': False,
#     'epsilon': 1.0,
#     'epsilon_start': 1.0,
#     'count_decay': 1.0,
#     'random_reward_start': False,
#     'fixed_gvf_path': None,
#     'replay': False,
#     'distributional': False,
#     'discounting': 0.9,
#     'k_rnn_hs': 1,
#     'er_hidden_update': None,
#     'atoms': 51,
#     'trace_decay': 0.9,
#     'same_k_rnn_params': False,
#     'value_step_size': 0.0001,
#     'max_episode_steps': 200,
#     'save_all_checkpoints': False,
#     'view_test_ep': False,
#     'size': 9,
#     'algo': 'sarsa',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'resample_interval': 1,
#     'po_degree': 0.0,
#     'unnormalized_counts': False,
#     'v_max': 100,
#     'optim': 'adam',
#     'test_eps': 0.0,
#     'weight_init': 'fan_avg',
#     'v_min': -10,
#     'platform': 'cpu',
#     'half_efficiency_distance': 20.0,
#     'init_hidden_var': 0.0,
#     'step_size': 1e-05,
#     'checkpoint_freq': 0,
#     'random_start': True,
#     'exploration': 'eps',
#     'n_hidden': 40,
#     'offline_eval_freq': 0,
#     'arch': 'nn',
#     'trunc': 10,
#     'layers': 1,
#     'update_weight_interval': 1,
#     'buffer_size': 20000,
#     'uncertainty_decay': 1.0,
#     'anneal_steps': 0,
#     'distance_unc_encoding': False,
#     'slip_prob': 0.0,
#     'action_cond': None,
#     'task_fname': 'task_{}_config.json',
#     'rock_obs_init': 0.0,
#     'distance_noise': False,
#     'save_model': False,
#     'seed': 2038,
#     'p_prefilled': 0.0,
#     'blur_prob': 0.3,
#     'env': '2t',
#     'n_particles': -1},
#    {'trace_decay': 0.9,
#     'epsilon_start': 1.0,
#     'same_k_rnn_params': False,
#     'save_all_checkpoints': False,
#     'save_model': False,
#     'k_rnn_hs': 1,
#     'unnormalized_counts': False,
#     'epsilon': 1.0,
#     'total_steps': 500000,
#     'optim': 'adam',
#     'blur_prob': 0.3,
#     'n_particles': -1,
#     'distributional': False,
#     'replay': False,
#     'trunc': 10,
#     'uncertainty_decay': 1.0,
#     'max_episode_steps': 200,
#     'buffer_size': 20000,
#     'slip_prob': 0.0,
#     'po_degree': 0.0,
#     'arch': 'nn',
#     'checkpoint_freq': 0,
#     'env': '2t',
#     'layers': 1,
#     'algo': 'sarsa',
#     'distance_unc_encoding': False,
#     'action_cond': None,
#     'seed': 2040,
#     'step_size': 1e-05,
#     'batch_size': 64,
#     'random_start': True,
#     'rock_obs_init': 0.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'atoms': 51,
#     'init_hidden_var': 0.0,
#     'size': 9,
#     'anneal_steps': 0,
#     'task_fname': 'task_{}_config.json',
#     'update_weight_interval': 1,
#     'test_episodes': 5,
#     'value_step_size': 0.0001,
#     'view_test_ep': False,
#     'exploration': 'eps',
#     'v_min': -10,
#     'random_reward_start': False,
#     'slip_turn': False,
#     'v_max': 100,
#     'p_prefilled': 0.0,
#     'er_hidden_update': None,
#     'offline_eval_freq': 0,
#     'count_decay': 1.0,
#     'fixed_gvf_path': None,
#     'distance_noise': False,
#     'discounting': 0.9,
#     'resample_interval': 1,
#     'n_hidden': 40,
#     'half_efficiency_distance': 20.0,
#     'test_eps': 0.0,
#     'weight_init': 'fan_avg',
#     'platform': 'cpu'},
#    {'same_k_rnn_params': False,
#     'value_step_size': 0.0001,
#     'rock_obs_init': 0.0,
#     'checkpoint_freq': 0,
#     'trunc': 10,
#     'arch': 'nn',
#     'unnormalized_counts': False,
#     'step_size': 1e-05,
#     'offline_eval_freq': 0,
#     'save_model': False,
#     'max_episode_steps': 200,
#     'batch_size': 64,
#     'er_hidden_update': None,
#     'p_prefilled': 0.0,
#     'n_hidden': 40,
#     'action_cond': None,
#     'trace_decay': 0.9,
#     'slip_prob': 0.0,
#     'total_steps': 500000,
#     'replay': False,
#     'v_max': 100,
#     'test_eps': 0.0,
#     'buffer_size': 20000,
#     'save_all_checkpoints': False,
#     'init_hidden_var': 0.0,
#     'random_reward_start': False,
#     'platform': 'cpu',
#     'seed': 2028,
#     'distance_unc_encoding': False,
#     'k_rnn_hs': 1,
#     'view_test_ep': False,
#     'random_start': True,
#     'resample_interval': 1,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'half_efficiency_distance': 20.0,
#     'test_episodes': 5,
#     'update_weight_interval': 1,
#     'exploration': 'eps',
#     'task_fname': 'task_{}_config.json',
#     'weight_init': 'fan_avg',
#     'v_min': -10,
#     'optim': 'adam',
#     'atoms': 51,
#     'discounting': 0.9,
#     'slip_turn': False,
#     'algo': 'sarsa',
#     'epsilon_start': 1.0,
#     'count_decay': 1.0,
#     'distance_noise': False,
#     'fixed_gvf_path': None,
#     'po_degree': 0.0,
#     'size': 9,
#     'uncertainty_decay': 1.0,
#     'n_particles': -1,
#     'epsilon': 1.0,
#     'anneal_steps': 0,
#     'blur_prob': 0.3,
#     'distributional': False,
#     'env': '2t',
#     'layers': 1},
#    {'platform': 'cpu',
#     'blur_prob': 0.3,
#     'action_cond': None,
#     'checkpoint_freq': 0,
#     'po_degree': 0.0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'replay': False,
#     'buffer_size': 20000,
#     'view_test_ep': False,
#     'random_reward_start': False,
#     'test_eps': 0.0,
#     'resample_interval': 1,
#     'count_decay': 1.0,
#     'offline_eval_freq': 0,
#     'max_episode_steps': 200,
#     'save_all_checkpoints': False,
#     'half_efficiency_distance': 20.0,
#     'random_start': True,
#     'exploration': 'eps',
#     'n_particles': -1,
#     'test_episodes': 5,
#     'distance_unc_encoding': False,
#     'size': 9,
#     'rock_obs_init': 0.0,
#     'same_k_rnn_params': False,
#     'uncertainty_decay': 1.0,
#     'unnormalized_counts': False,
#     'trunc': 10,
#     'distributional': False,
#     'er_hidden_update': None,
#     'update_weight_interval': 1,
#     'fixed_gvf_path': None,
#     'batch_size': 64,
#     'init_hidden_var': 0.0,
#     'weight_init': 'fan_avg',
#     'epsilon_start': 1.0,
#     'arch': 'nn',
#     'seed': 2022,
#     'v_min': -10,
#     'n_hidden': 40,
#     'total_steps': 500000,
#     'distance_noise': False,
#     'k_rnn_hs': 1,
#     'epsilon': 1.0,
#     'slip_prob': 0.0,
#     'anneal_steps': 0,
#     'algo': 'sarsa',
#     'save_model': False,
#     'trace_decay': 0.9,
#     'layers': 1,
#     'slip_turn': False,
#     'optim': 'adam',
#     'env': '2t',
#     'step_size': 1e-05,
#     'atoms': 51,
#     'p_prefilled': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'value_step_size': 0.0001,
#     'discounting': 0.9,
#     'v_max': 100},
#    {'v_max': 100,
#     'p_prefilled': 0.0,
#     'distance_noise': False,
#     'same_k_rnn_params': False,
#     'replay': False,
#     'trunc': 10,
#     'er_hidden_update': None,
#     'max_episode_steps': 200,
#     'seed': 2020,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'total_steps': 500000,
#     'unnormalized_counts': False,
#     'step_size': 1e-05,
#     'algo': 'sarsa',
#     'test_episodes': 5,
#     'anneal_steps': 0,
#     'save_all_checkpoints': False,
#     'action_cond': None,
#     'random_reward_start': False,
#     'blur_prob': 0.3,
#     'v_min': -10,
#     'k_rnn_hs': 1,
#     'layers': 1,
#     'random_start': True,
#     'batch_size': 64,
#     'optim': 'adam',
#     'slip_prob': 0.0,
#     'epsilon_start': 1.0,
#     'env': '2t',
#     'rock_obs_init': 0.0,
#     'uncertainty_decay': 1.0,
#     'checkpoint_freq': 0,
#     'distributional': False,
#     'fixed_gvf_path': None,
#     'test_eps': 0.0,
#     'init_hidden_var': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'n_particles': -1,
#     'exploration': 'eps',
#     'distance_unc_encoding': False,
#     'resample_interval': 1,
#     'platform': 'cpu',
#     'atoms': 51,
#     'save_model': False,
#     'view_test_ep': False,
#     'arch': 'nn',
#     'po_degree': 0.0,
#     'buffer_size': 20000,
#     'n_hidden': 40,
#     'offline_eval_freq': 0,
#     'size': 9,
#     'discounting': 0.9,
#     'count_decay': 1.0,
#     'trace_decay': 0.9,
#     'half_efficiency_distance': 20.0,
#     'slip_turn': False,
#     'weight_init': 'fan_avg',
#     'value_step_size': 0.0001,
#     'update_weight_interval': 1,
#     'epsilon': 1.0},
#    {'replay': False,
#     'half_efficiency_distance': 20.0,
#     'env': '2t',
#     'same_k_rnn_params': False,
#     'distributional': False,
#     'batch_size': 64,
#     'epsilon_start': 1.0,
#     'v_min': -10,
#     'er_hidden_update': None,
#     'random_reward_start': False,
#     'test_eps': 0.0,
#     'fixed_gvf_path': None,
#     'save_model': False,
#     'seed': 2029,
#     'blur_prob': 0.3,
#     'platform': 'cpu',
#     'trunc': 10,
#     'k_rnn_hs': 1,
#     'value_step_size': 0.0001,
#     'algo': 'sarsa',
#     'anneal_steps': 0,
#     'epsilon': 1.0,
#     'uncertainty_decay': 1.0,
#     'exploration': 'eps',
#     'test_episodes': 5,
#     'slip_prob': 0.0,
#     'trace_decay': 0.9,
#     'v_max': 100,
#     'distance_noise': False,
#     'buffer_size': 20000,
#     'unnormalized_counts': False,
#     'update_weight_interval': 1,
#     'discounting': 0.9,
#     'weight_init': 'fan_avg',
#     'random_start': True,
#     'view_test_ep': False,
#     'layers': 1,
#     'distance_unc_encoding': False,
#     'optim': 'adam',
#     'offline_eval_freq': 0,
#     'checkpoint_freq': 0,
#     'atoms': 51,
#     'max_episode_steps': 200,
#     'save_all_checkpoints': False,
#     'size': 9,
#     'arch': 'nn',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'n_hidden': 40,
#     'slip_turn': False,
#     'action_cond': None,
#     'step_size': 1e-05,
#     'p_prefilled': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'n_particles': -1,
#     'total_steps': 500000,
#     'po_degree': 0.0,
#     'resample_interval': 1,
#     'init_hidden_var': 0.0,
#     'rock_obs_init': 0.0,
#     'count_decay': 1.0},
#    {'atoms': 51,
#     'blur_prob': 0.3,
#     'checkpoint_freq': 0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'size': 9,
#     'count_decay': 1.0,
#     'replay': False,
#     'max_episode_steps': 200,
#     'same_k_rnn_params': False,
#     'distance_unc_encoding': False,
#     'unnormalized_counts': False,
#     'exploration': 'eps',
#     'n_particles': -1,
#     'fixed_gvf_path': None,
#     'distance_noise': False,
#     'action_cond': None,
#     'discounting': 0.9,
#     'arch': 'nn',
#     'batch_size': 64,
#     'trunc': 10,
#     'optim': 'adam',
#     'k_rnn_hs': 1,
#     'distributional': False,
#     'po_degree': 0.0,
#     'er_hidden_update': None,
#     'random_reward_start': False,
#     'update_weight_interval': 1,
#     'weight_init': 'fan_avg',
#     'uncertainty_decay': 1.0,
#     'epsilon': 1.0,
#     'test_eps': 0.0,
#     'platform': 'cpu',
#     'step_size': 1e-05,
#     'anneal_steps': 0,
#     'buffer_size': 20000,
#     'v_min': -10,
#     'value_step_size': 0.0001,
#     'v_max': 100,
#     'layers': 1,
#     'random_start': True,
#     'trace_decay': 0.9,
#     'total_steps': 500000,
#     'save_model': False,
#     'slip_prob': 0.0,
#     'epsilon_start': 1.0,
#     'init_hidden_var': 0.0,
#     'view_test_ep': False,
#     'test_episodes': 5,
#     'slip_turn': False,
#     'resample_interval': 1,
#     'offline_eval_freq': 0,
#     'task_fname': 'task_{}_config.json',
#     'n_hidden': 40,
#     'seed': 2026,
#     'algo': 'sarsa',
#     'half_efficiency_distance': 20.0,
#     'p_prefilled': 0.0,
#     'save_all_checkpoints': False,
#     'env': '2t',
#     'rock_obs_init': 0.0},
#    {'init_hidden_var': 0.0,
#     'distance_unc_encoding': False,
#     'distributional': False,
#     'value_step_size': 0.0001,
#     'anneal_steps': 0,
#     'atoms': 51,
#     'random_start': True,
#     'replay': False,
#     'layers': 1,
#     'view_test_ep': False,
#     'slip_turn': False,
#     'count_decay': 1.0,
#     'arch': 'nn',
#     'half_efficiency_distance': 20.0,
#     'platform': 'cpu',
#     'distance_noise': False,
#     'unnormalized_counts': False,
#     'trace_decay': 0.9,
#     'k_rnn_hs': 1,
#     'resample_interval': 1,
#     'v_max': 100,
#     'po_degree': 0.0,
#     'env': '2t',
#     'exploration': 'eps',
#     'seed': 2047,
#     'task_fname': 'task_{}_config.json',
#     'n_particles': -1,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'epsilon': 1.0,
#     'n_hidden': 40,
#     'epsilon_start': 1.0,
#     'offline_eval_freq': 0,
#     'blur_prob': 0.3,
#     'v_min': -10,
#     'trunc': 10,
#     'fixed_gvf_path': None,
#     'batch_size': 64,
#     'uncertainty_decay': 1.0,
#     'weight_init': 'fan_avg',
#     'algo': 'sarsa',
#     'action_cond': None,
#     'slip_prob': 0.0,
#     'rock_obs_init': 0.0,
#     'save_model': False,
#     'checkpoint_freq': 0,
#     'same_k_rnn_params': False,
#     'discounting': 0.9,
#     'p_prefilled': 0.0,
#     'test_episodes': 5,
#     'size': 9,
#     'total_steps': 500000,
#     'random_reward_start': False,
#     'max_episode_steps': 200,
#     'step_size': 1e-05,
#     'test_eps': 0.0,
#     'save_all_checkpoints': False,
#     'er_hidden_update': None,
#     'buffer_size': 20000,
#     'optim': 'adam',
#     'update_weight_interval': 1},
#    {'action_cond': None,
#     'save_model': False,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'slip_prob': 0.0,
#     'random_start': True,
#     'test_episodes': 5,
#     'resample_interval': 1,
#     'task_fname': 'task_{}_config.json',
#     'save_all_checkpoints': False,
#     'epsilon_start': 1.0,
#     'value_step_size': 0.0001,
#     'n_hidden': 40,
#     'fixed_gvf_path': None,
#     'v_max': 100,
#     'size': 9,
#     'po_degree': 0.0,
#     'env': '2t',
#     'blur_prob': 0.3,
#     'platform': 'cpu',
#     'count_decay': 1.0,
#     'batch_size': 64,
#     'k_rnn_hs': 1,
#     'offline_eval_freq': 0,
#     'view_test_ep': False,
#     'distributional': False,
#     'anneal_steps': 0,
#     'init_hidden_var': 0.0,
#     'step_size': 1e-05,
#     'layers': 1,
#     'replay': False,
#     'slip_turn': False,
#     'trace_decay': 0.9,
#     'weight_init': 'fan_avg',
#     'n_particles': -1,
#     'seed': 2044,
#     'distance_noise': False,
#     'trunc': 10,
#     'test_eps': 0.0,
#     'checkpoint_freq': 0,
#     'half_efficiency_distance': 20.0,
#     'unnormalized_counts': False,
#     'p_prefilled': 0.0,
#     'same_k_rnn_params': False,
#     'update_weight_interval': 1,
#     'random_reward_start': False,
#     'discounting': 0.9,
#     'algo': 'sarsa',
#     'distance_unc_encoding': False,
#     'max_episode_steps': 200,
#     'total_steps': 500000,
#     'epsilon': 1.0,
#     'exploration': 'eps',
#     'rock_obs_init': 0.0,
#     'atoms': 51,
#     'v_min': -10,
#     'optim': 'adam',
#     'uncertainty_decay': 1.0,
#     'er_hidden_update': None,
#     'buffer_size': 20000,
#     'arch': 'nn'},
#    {'platform': 'cpu',
#     'task_fname': 'task_{}_config.json',
#     'n_particles': -1,
#     'slip_turn': False,
#     'half_efficiency_distance': 20.0,
#     'unnormalized_counts': False,
#     'discounting': 0.9,
#     'batch_size': 64,
#     'max_episode_steps': 200,
#     'n_hidden': 40,
#     'weight_init': 'fan_avg',
#     'test_episodes': 5,
#     'value_step_size': 0.0001,
#     'epsilon_start': 1.0,
#     'anneal_steps': 0,
#     'algo': 'sarsa',
#     'blur_prob': 0.3,
#     'checkpoint_freq': 0,
#     'action_cond': None,
#     'uncertainty_decay': 1.0,
#     'po_degree': 0.0,
#     'replay': False,
#     'test_eps': 0.0,
#     'exploration': 'eps',
#     'total_steps': 500000,
#     'save_all_checkpoints': False,
#     'offline_eval_freq': 0,
#     'atoms': 51,
#     'seed': 2024,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'k_rnn_hs': 1,
#     'random_start': True,
#     'distance_unc_encoding': False,
#     'epsilon': 1.0,
#     'optim': 'adam',
#     'p_prefilled': 0.0,
#     'layers': 1,
#     'size': 9,
#     'fixed_gvf_path': None,
#     'random_reward_start': False,
#     'slip_prob': 0.0,
#     'er_hidden_update': None,
#     'v_max': 100,
#     'buffer_size': 20000,
#     'env': '2t',
#     'init_hidden_var': 0.0,
#     'step_size': 1e-05,
#     'update_weight_interval': 1,
#     'resample_interval': 1,
#     'distributional': False,
#     'trace_decay': 0.9,
#     'rock_obs_init': 0.0,
#     'view_test_ep': False,
#     'distance_noise': False,
#     'v_min': -10,
#     'save_model': False,
#     'arch': 'nn',
#     'count_decay': 1.0,
#     'same_k_rnn_params': False,
#     'trunc': 10},
#    {'update_weight_interval': 1,
#     'save_model': False,
#     'trunc': 10,
#     'p_prefilled': 0.0,
#     'max_episode_steps': 200,
#     'size': 9,
#     'total_steps': 500000,
#     'distance_noise': False,
#     'anneal_steps': 0,
#     'trace_decay': 0.9,
#     'unnormalized_counts': False,
#     'arch': 'nn',
#     'exploration': 'eps',
#     'resample_interval': 1,
#     'algo': 'sarsa',
#     'random_start': True,
#     'uncertainty_decay': 1.0,
#     'random_reward_start': False,
#     'er_hidden_update': None,
#     'buffer_size': 20000,
#     'platform': 'cpu',
#     'slip_turn': False,
#     'step_size': 1e-05,
#     'offline_eval_freq': 0,
#     'optim': 'adam',
#     'slip_prob': 0.0,
#     'task_fname': 'task_{}_config.json',
#     'value_step_size': 0.0001,
#     'blur_prob': 0.3,
#     'save_all_checkpoints': False,
#     'action_cond': None,
#     'epsilon_start': 1.0,
#     'distributional': False,
#     'n_particles': -1,
#     'batch_size': 64,
#     'layers': 1,
#     'init_hidden_var': 0.0,
#     'count_decay': 1.0,
#     'k_rnn_hs': 1,
#     'v_max': 100,
#     'test_eps': 0.0,
#     'discounting': 0.9,
#     'replay': False,
#     'weight_init': 'fan_avg',
#     'fixed_gvf_path': None,
#     'test_episodes': 5,
#     'epsilon': 1.0,
#     'n_hidden': 40,
#     'same_k_rnn_params': False,
#     'distance_unc_encoding': False,
#     'half_efficiency_distance': 20.0,
#     'rock_obs_init': 0.0,
#     'view_test_ep': False,
#     'seed': 2042,
#     'v_min': -10,
#     'po_degree': 0.0,
#     'atoms': 51,
#     'env': '2t',
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'checkpoint_freq': 0},
#    {'uncertainty_decay': 1.0,
#     'same_k_rnn_params': False,
#     'slip_turn': False,
#     'p_prefilled': 0.0,
#     'trace_decay': 0.9,
#     'size': 9,
#     'algo': 'sarsa',
#     'epsilon_start': 1.0,
#     'task_fname': 'task_{}_config.json',
#     'buffer_size': 20000,
#     'discounting': 0.9,
#     'distance_noise': False,
#     'atoms': 51,
#     'n_particles': -1,
#     'checkpoint_freq': 0,
#     'v_max': 100,
#     'action_cond': None,
#     'fixed_gvf_path': None,
#     'step_size': 1e-05,
#     'exploration': 'eps',
#     'test_episodes': 5,
#     'half_efficiency_distance': 20.0,
#     'layers': 1,
#     'random_start': True,
#     'epsilon': 1.0,
#     'distributional': False,
#     'resample_interval': 1,
#     'total_steps': 500000,
#     'er_hidden_update': None,
#     'anneal_steps': 0,
#     'results_dir': PosixPath('/home/taodav/scratch/uncertainty/results/2t_nn'),
#     'distance_unc_encoding': False,
#     'weight_init': 'fan_avg',
#     'n_hidden': 40,
#     'init_hidden_var': 0.0,
#     'max_episode_steps': 200,
#     'unnormalized_counts': False,
#     'slip_prob': 0.0,
#     'po_degree': 0.0,
#     'rock_obs_init': 0.0,
#     'replay': False,
#     'arch': 'nn',
#     'random_reward_start': False,
#     'test_eps': 0.0,
#     'optim': 'adam',
#     'count_decay': 1.0,
#     'view_test_ep': False,
#     'save_all_checkpoints': False,
#     'platform': 'cpu',
#     'seed': 2034,
#     'k_rnn_hs': 1,
#     'value_step_size': 0.0001,
#     'env': '2t',
#     'update_weight_interval': 1,
#     'save_model': False,
#     'offline_eval_freq': 0,
#     'blur_prob': 0.3,
#     'batch_size': 64,
#     'v_min': -10,
#     'trunc': 10}],
#   [PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/82983a3aeb77cab5ff99cc8b279f585e_Wed Jul 13 15:09:56 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/212d8b73f0e02d603228d73d7dd0d4fd_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/cc7a6485f85fee2267e9fe96f994d905_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/e8a76e9e3d785bb2dea1eb7cb6fdf21d_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/f4819bc6e04331f4906b56c511259c74_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/0c6f8343c7cc11638dcef44ec2297e73_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/effc99688b8f9f0a5a88dc459c6ae342_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/2c703f6b5519a5cd91b7e33fde0edb92_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/aaff5572dd6876c850c630e7840036f0_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/4d67f9a399f50d11766ad7e692f0cb9f_Wed Jul 13 15:05:16 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/4ab7ed759922f8843dd157e57a3b8057_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/5d182cda1f660d2b47fc5cc3bcbad06a_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/8a24b4c4e15bcd254cd9361b4655f98d_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/eebcf46aa90fc7ce74c20ecd30457eb7_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/261e911ce329422faf4eae142ce164fc_Wed Jul 13 15:09:56 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/a01ba06fac7887a64593a6484ea5a0c6_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/9055cfdc7f6f7576eabff8f944c828c4_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/68250a90121503cef1662350be379794_Wed Jul 13 15:05:16 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/55f4e74a5a0adbe9b764f6a6d08c00a3_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/4cf2ee18eb980ee8733f5101f157c8dc_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/de3da12030b8716abfe082468bcfb505_Wed Jul 13 15:09:56 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/f7b47276af700ee8c396abb284ccac40_Wed Jul 13 15:05:16 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/e23112c347f3a9a9c4a55ba20a45147a_Wed Jul 13 15:05:16 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/48c063318dec1314c12cb6f85e5ba5af_Wed Jul 13 15:09:56 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/fd30e68ccae92fd608dae4f7ea527557_Wed Jul 13 15:09:56 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/f696c02cbc06c4366d398e05d2a32169_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/1fdda474b58e1200ca896e1a146deffe_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/49571fb336289d48c1bae6d512af64bf_Wed Jul 13 15:05:16 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/e223ee2d1aa4c8b702120a8cabbe5aa6_Wed Jul 13 15:19:45 2022.npy'),
#    PosixPath('/Users/ruoyutao/Documents/uncertainty/results/2t_nn_prediction/69c5c45b4b7aeb3bc14003c03bc3702a_Wed Jul 13 15:19:45 2022.npy')])]

# %%
# Checkpoint directories are sorted by seed.
checkpoint_dirs = [None for i in range(len(all_best['2t_nn_prediction'][-2]))]


for arg, path in zip(all_best['2t_nn_prediction'][-2], all_best['2t_nn_prediction'][-1]):
    checkpoints_dir = path.parent / 'checkpoints'
    arg_checkpoint_name = path.name.split('_')[0]
    arg_checkpoint_dir = checkpoints_dir / arg_checkpoint_name
    latest_checkpoint_name = sorted(list(arg_checkpoint_dir.iterdir()))[-1].name
    slurm_results_dir = Path('/home/taodav/scratch/uncertainty/results/2t_nn_prediction')
    slurm_checkpoint_fname = slurm_results_dir / 'checkpoints' / arg_checkpoint_name / latest_checkpoint_name
    checkpoint_dirs[arg['seed'] - 2020] = str(slurm_checkpoint_fname)

# %%
checkpoint_dirs[:30]
# Out:
# ['/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/3b0cd57081bfd8ac0bcc37708091119c/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/8edd78bdf60ea6a0e31be780ec2141ef/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/c0c05b42d05fa5fb3ee3361fd10077b1/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/789a2dfaecd896fc125ea87390f76970/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/862d45c24e9629e23d726eff5d7767fc/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/05184069ec1e8fe996aa3eaf417d9c1b/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/43065c6b09b65de0840836b674ba78a7/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/c3868a1bfe69cc0135619af24456c50a/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/d2e98c6d76ea5624ba39ba9b916c2eb7/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/357205be7114fa93d22d70e0f3cba135/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/5c6540ef61679b69881fc6850b6ce384/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/2cecd0d8b889ed0cda793a20b0ea64e1/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/9768cf92b5c7d17692e206c0c96ff984/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/272d67c48431b968e53667c2b686c7bd/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/2d65ae967c1ef00b52ed6d1986d4ff72/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/2673e1d58a0111851613c081b8e80025/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/cbdec9cd0dfdadfe5905bb2397d4272b/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/5f2f4670630e09975bafdfeb8594e26b/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/167d71c763fdf5d51ff069cf502e4c7b/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/1e0b582b87de84a21a416611dda12587/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/6b985c7ef254bdee49ddac7faadc0f43/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/8b5a67785f514e8797bd9527f7bfb49e/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/19fe59da28bb5d54523490bb1b05ad23/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/cc0c81db9a8d0766909f591ccc965370/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/36ca2ba08cef1ed8a4c26fc5641c26a9/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/becf66453f61f15418b15089d086b0ba/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/d762e40a160d9e2a9953ad7fc83730d0/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/9a7ecb17d2a75f783c722e060fcf75a3/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/0343c13b591573bb555d342d3b0af6dd/500000.pkl',
#  '/home/taodav/scratch/uncertainty/results/2t_nn_prediction/checkpoints/cc544f49b531c80ac26ce46d50bc488c/500000.pkl']
